# %%
import sys

sys.path.append('../')
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "1"
import glob

from keras.optimizers import Adam, SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TerminateOnNaN, CSVLogger, TensorBoard
from keras import backend as K
from keras.models import load_model
from math import ceil
import numpy as np
from matplotlib import pyplot as plt

from models.keras_ssd512_Siamese import ssd_512
from keras_loss_function.keras_ssd_loss import SSDLoss
from keras_layers.keras_layer_AnchorBoxes import AnchorBoxes
from keras_layers.keras_layer_DecodeDetections import DecodeDetections
from keras_layers.keras_layer_DecodeDetectionsFast import DecodeDetectionsFast
from keras_layers.keras_layer_L2Normalization import L2Normalization

from ssd_encoder_decoder.ssd_input_encoder import SSDInputEncoder
from ssd_encoder_decoder.ssd_output_decoder import decode_detections, decode_detections_fast

from data_generator.object_detection_2d_data_generator import DataGenerator
from data_generator.object_detection_2d_geometric_ops import Resize
from data_generator.object_detection_2d_photometric_ops import ConvertTo3Channels
from data_generator.data_augmentation_chain_original_ssd import SSDDataAugmentation, SSDDataAugmentation_Siamese
from data_generator.object_detection_2d_misc_utils import apply_inverse_transforms

img_height = 512  # Height of the model input images
img_width = 512  # Width of the model input images
img_channels = 3  # Number of color channels of the model input images
mean_color = [123, 117, 104]  # Per-channel mean of images. Do not change if use any of the pre-trained weights.
# The color channel order in the original SSD is BGR,
# so we'll have the model reverse the color channel order of the input images.
swap_channels = [2, 1, 0]
# The anchor box scaling factors used in the original SSD512 for the Pascal VOC datasets
# scales_pascal =
# The anchor box scaling factors used in the original SSD512 for the MS COCO datasets
scales_coco = [0.07, 0.15, 0.3, 0.45, 0.6, 0.75, 0.9, 1.05]
scales = scales_coco
aspect_ratios = [[1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5, 3.0, 1.0 / 3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0 / 3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0 / 3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0 / 3.0],
                 [1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5]]  # The anchor box aspect ratios used in the original SSD512; the order matters
two_boxes_for_ar1 = True
steps = [8, 16, 32, 64, 128, 256, 512]  # Space between two adjacent anchor box center points for each predictor layer.
# The offsets of the first anchor box center points from the top and left borders of the image
# as a fraction of the step size for each predictor layer.
offsets = [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
clip_boxes = False  # Whether or not to clip the anchor boxes to lie entirely within the image boundaries
# The variances by which the encoded target coordinates are divided as in the original implementation
variances = [0.1, 0.1, 0.2, 0.2]
normalize_coords = True
Model_Build = 'New_Model'  # 'Load_Model'
Optimizer_Type = 'SGD'  # 'Adam'  #
# Different batch_size will have different prediction loss.
batch_size = 6  # Change the batch size if you like, or if you run into GPU memory issues.
# alpha_distance = 0.0001  # Coefficient for the distance between the source and target feature maps.
G_loss_weights = [0.0001, 1.0]
D_loss_weights = [0.0001, 0.0001]

# 'City_to_foggy0_01_resize_600_1200' # 'City_to_foggy0_02_resize_600_1200'  # 'SIM10K_to_VOC07'
# 'SIM10K'  # 'Cityscapes_foggy_beta_0_01'  #  'City_to_foggy0_02_resize_400_800'
# 'SIM10K_to_VOC12_resize_400_800'
DatasetName = 'SIM10K_to_City_resize_400_800' # 'SIM10K_to_VOC07_resize_400_800'  # 'City_to_foggy0_01_resize_400_800'  # 
processed_dataset_path = './processed_dataset_h5/' + DatasetName
if not os.path.exists(processed_dataset_path):
    os.makedirs(processed_dataset_path)

checkpoint_path = '../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001'
if not os.path.exists(checkpoint_path):
    os.makedirs(checkpoint_path)
    
csv_file_name = 'training_log.csv'    
    
if len(glob.glob(os.path.join(processed_dataset_path, '*.h5'))):
    Dataset_Build = 'Load_Dataset'
else:
    Dataset_Build = 'New_Dataset'

if DatasetName == 'SIM10K_to_VOC12_resize_400_800':
    resize_image_to = (400, 800)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/VOCdevkit/VOC2012/JPEGImages'
    test_target_images_dir = '../../datasets/VOCdevkit/VOC2012/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/VOCdevkit/VOC2012/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    # The trainset of VOC which has 'car' object is used as train_target.
    train_target_image_set_filename = '../../datasets/VOCdevkit/VOC2012_CAR/ImageSets/Main/train_target.txt'
    # The valset of VOC which has 'car' object is used as test.
    test_target_image_set_filename = '../../datasets/VOCdevkit/VOC2012_CAR/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car',
                   'aeroplane', 'bicycle', 'bird', 'boat',
                   'bottle', 'bus', 'cat',
                   'chair', 'cow', 'diningtable', 'dog',
                   'horse', 'motorbike', 'person', 'pottedplant',
                   'sheep', 'sofa', 'train', 'tvmonitor']
    val_include_classes = [val_classes.index(one_class) for one_class in classes[1:]]
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'SIM10K_to_VOC07_resize_400_800':
    resize_image_to = (400, 800)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/VOCdevkit/VOC2007/JPEGImages'
    test_target_images_dir = '../../datasets/VOCdevkit/VOC2007/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/VOCdevkit/VOC2007/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    # The trainset of VOC which has 'car' object is used as train_target.
    train_target_image_set_filename = '../../datasets/VOCdevkit/VOC2007_CAR/ImageSets/Main/train_target.txt'
    # The valset of VOC which has 'car' object is used as test.
    test_target_image_set_filename = '../../datasets/VOCdevkit/VOC2007_CAR/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car',
                   'aeroplane', 'bicycle', 'bird', 'boat',
                   'bottle', 'bus', 'cat',
                   'chair', 'cow', 'diningtable', 'dog',
                   'horse', 'motorbike', 'person', 'pottedplant',
                   'sheep', 'sofa', 'train', 'tvmonitor']
    val_include_classes = [val_classes.index(one_class) for one_class in classes[1:]]
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'SIM10K_to_City_resize_400_800':
    resize_image_to = (400, 800)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/Cityscapes/JPEGImages'
    test_target_images_dir = '../../datasets/val_data_for_SIM10K_to_cityscapes/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/val_data_for_SIM10K_to_cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    test_target_image_set_filename = '../../datasets/val_data_for_SIM10K_to_cityscapes/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car']
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'City_to_foggy0_02_resize_400_800':
    resize_image_to = (400, 800)
    # Introduction of PascalVOC: https://arleyzhang.github.io/articles/1dc20586/
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/Cityscapes/JPEGImages'
    train_target_images_dir = '../../datasets/Cityscapes/JPEGImages'
    test_target_images_dir = '../../datasets/Cityscapes/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/Cityscapes/Annotations'
    test_annotation_dir = '../../datasets/Cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_target.txt'
    test_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/test.txt'
    # Our model will produce predictions for these classes.
    classes = ['background',
               'person', 'rider', 'car', 'truck',
               'bus', 'train', 'motorcycle', 'bicycle']
    train_classes = classes
    train_include_classes = 'all'
    val_classes = classes
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'City_to_foggy0_01_resize_400_800':
    resize_image_to = (400, 800)
    # Introduction of PascalVOC: https://arleyzhang.github.io/articles/1dc20586/
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/Cityscapes/JPEGImages'
    train_target_images_dir = '../../datasets/CITYSCAPES_beta_0_01/JPEGImages'
    test_target_images_dir = '../../datasets/CITYSCAPES_beta_0_01/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/Cityscapes/Annotations'
    test_annotation_dir = '../../datasets/Cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_target.txt'
    test_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/test.txt'
    # Our model will produce predictions for these classes.
    classes = ['background',
               'person', 'rider', 'car', 'truck',
               'bus', 'train', 'motorcycle', 'bicycle']
    train_classes = classes
    train_include_classes = 'all'
    val_classes = classes
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

else:
    raise ValueError('Undefined dataset name.')
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
if Model_Build == 'New_Model':
    # 1: Build the Keras model.

    K.clear_session()  # Clear previous models from memory.

    import tensorflow as tf
    from keras.backend.tensorflow_backend import set_session

    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
    config.log_device_placement = True  # to log device placement (on which device the operation ran)
    # (nothing gets printed in Jupyter, only if you run it standalone)
    sess = tf.Session(config=config)
    set_session(sess)  # set this TensorFlow session as the default session for Keras

    D_model, G_model = ssd_512(image_size=(img_height, img_width, img_channels),
                               n_classes=n_classes,
                               G_loss_weights=G_loss_weights,
                               D_loss_weights=D_loss_weights,
                               mode='training',
                               l2_regularization=0.0005,
                               scales=scales,
                               aspect_ratios_per_layer=aspect_ratios,
                               two_boxes_for_ar1=two_boxes_for_ar1,
                               steps=steps,
                               offsets=offsets,
                               clip_boxes=clip_boxes,
                               variances=variances,
                               normalize_coords=normalize_coords,
                               subtract_mean=mean_color,
                               swap_channels=swap_channels)

else:
    raise ValueError('Undefined Model_Build. Model_Build should be New_Model  or Load_Model')
# Out:
# D_network is Conv2

# %%
if Dataset_Build == 'New_Dataset':
    # 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

    # Optional: If you have enough memory, consider loading the images into memory for the reasons explained above.

    train_dataset = DataGenerator(dataset='train', load_images_into_memory=False, hdf5_dataset_path=None)
    val_dataset = DataGenerator(dataset='val', load_images_into_memory=False, hdf5_dataset_path=None)

    # 2: Parse the image and label lists for the training and validation datasets. This can take a while.
    # images_dirs, image_set_filenames, and annotations_dirs should have the same length
    train_dataset.parse_xml(images_dirs=[train_source_images_dir],
                            target_images_dirs=[train_target_images_dir],
                            image_set_filenames=[train_source_image_set_filename],
                            target_image_set_filenames=[train_target_image_set_filename],
                            annotations_dirs=[train_annotation_dir],
                            classes=train_classes,
                            include_classes=train_include_classes,
                            exclude_truncated=False,
                            exclude_difficult=False,
                            ret=False)

    val_dataset.parse_xml(images_dirs=[test_target_images_dir],
                          image_set_filenames=[test_target_image_set_filename],
                          annotations_dirs=[test_annotation_dir],
                          classes=val_classes,
                          include_classes=val_include_classes,
                          exclude_truncated=False,
                          exclude_difficult=True,
                          ret=False)

    # Optional: Convert the dataset into an HDF5 dataset. This will require more disk space, but will
    # speed up the training. Doing this is not relevant in case you activated the `load_images_into_memory`
    # option in the constructor, because in that cas the images are in memory already anyway. If you don't
    # want to create HDF5 datasets, comment out the subsequent two function calls.

    # After create these h5 files, if you have resized the input image, you need to reload these files. Otherwise,
    # the images and the labels will not change.

    train_dataset.create_hdf5_dataset(file_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                      resize=resize_image_to,
                                      variable_image_size=True,
                                      verbose=True)

    val_dataset.create_hdf5_dataset(file_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                    resize=False,
                                    variable_image_size=True,
                                    verbose=True)

    train_dataset = DataGenerator(dataset='train',
                                  load_images_into_memory=False,
                                  hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                  filenames=train_source_image_set_filename,
                                  target_filenames=train_target_image_set_filename,
                                  filenames_type='text',
                                  images_dir=train_source_images_dir,
                                  target_images_dir=train_target_images_dir)

    val_dataset = DataGenerator(dataset='val',
                                load_images_into_memory=False,
                                hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                filenames=test_target_image_set_filename,
                                filenames_type='text',
                                images_dir=test_target_images_dir)

elif Dataset_Build == 'Load_Dataset':
    # 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

    # Load dataset from the created h5 file.
    train_dataset = DataGenerator(dataset='train',
                                  load_images_into_memory=False,
                                  hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                  filenames=train_source_image_set_filename,
                                  target_filenames=train_target_image_set_filename,
                                  filenames_type='text',
                                  images_dir=train_source_images_dir,
                                  target_images_dir=train_target_images_dir)

    val_dataset = DataGenerator(dataset='val',
                                load_images_into_memory=False,
                                hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                filenames=test_target_image_set_filename,
                                filenames_type='text',
                                images_dir=test_target_images_dir)

else:
    raise ValueError('Undefined Dataset_Build. Dataset_Build should be New_Dataset or Load_Dataset.')
# Out:
# Loading source labels: 100%|██████████| 10000/10000 [00:02<00:00, 4687.25it/s]
# Loading source image IDs: 100%|██████████| 10000/10000 [00:00<00:00, 10792.60it/s]
# Loading target image IDs: 100%|██████████| 2966/2966 [00:00<00:00, 10706.21it/s]
# Loading evaluation-neutrality annotations: 100%|██████████| 10000/10000 [00:01<00:00, 7596.08it/s]
# Loading source labels: 100%|██████████| 479/479 [00:00<00:00, 4651.83it/s]
# Loading source image IDs: 100%|██████████| 479/479 [00:00<00:00, 10051.59it/s]
# Loading target image IDs: 0it [00:00, ?it/s]
# Loading evaluation-neutrality annotations: 100%|██████████| 479/479 [00:00<00:00, 5118.12it/s]

# %%
# 4: Set the image transformations for pre-processing and data augmentation options.

# For the training generator:
ssd_data_augmentation = SSDDataAugmentation_Siamese(img_height=img_height,
                                                    img_width=img_width)

# For the validation generator:
convert_to_3_channels = ConvertTo3Channels()
resize = Resize(height=img_height, width=img_width)

# 5: Instantiate an encoder that can encode ground truth labels into the format needed by the SSD loss function.

# The encoder constructor needs the spatial dimensions of the model's predictor layers to create the anchor boxes.
predictor_sizes = [G_model.get_layer('conv4_3_norm_mbox_conf').output_shape[1:3],
                   G_model.get_layer('fc7_mbox_conf').output_shape[1:3],
                   G_model.get_layer('conv6_2_mbox_conf').output_shape[1:3],
                   G_model.get_layer('conv7_2_mbox_conf').output_shape[1:3],
                   G_model.get_layer('conv8_2_mbox_conf').output_shape[1:3],
                   G_model.get_layer('conv9_2_mbox_conf').output_shape[1:3],
                   G_model.get_layer('conv10_2_mbox_conf').output_shape[1:3]]

ssd_input_encoder = SSDInputEncoder(img_height=img_height,
                                    img_width=img_width,
                                    n_classes=n_classes,
                                    predictor_sizes=predictor_sizes,
                                    scales=scales,
                                    aspect_ratios_per_layer=aspect_ratios,
                                    two_boxes_for_ar1=two_boxes_for_ar1,
                                    steps=steps,
                                    offsets=offsets,
                                    clip_boxes=clip_boxes,
                                    variances=variances,
                                    matching_type='multi',
                                    pos_iou_threshold=0.5,
                                    neg_iou_limit=0.5,
                                    normalize_coords=normalize_coords)

# 6: Create the generator handles that will be passed to Keras' `fit_generator()` function.
# The input image and label are first processed by transformations. Then, the label will be further encoded by
# ssd_input_encoder. The encoded labels are classId and offset to each anchor box.
# G_train_generator = train_dataset.generate(batch_size=batch_size,
#                                            generator_type='G',
#                                            shuffle=True,
#                                            transformations=[ssd_data_augmentation],
#                                            label_encoder=ssd_input_encoder,
#                                            returns={'processed_images',
#                                                     'encoded_labels'},
#                                            keep_images_without_gt=False)

# D_train_generator = train_dataset.generate(batch_size=batch_size,
#                                            generator_type='D',
#                                            shuffle=True,
#                                            transformations=[ssd_data_augmentation],
#                                            label_encoder=ssd_input_encoder,
#                                            returns={'processed_images',
#                                                     'encoded_labels'},
#                                            keep_images_without_gt=False)

# val_generator = val_dataset.generate(batch_size=batch_size,
#                                      generator_type='G',
#                                      shuffle=False,
#                                      transformations=[convert_to_3_channels,
#                                                       resize],
#                                      label_encoder=ssd_input_encoder,
#                                      returns={'processed_images',
#                                               'encoded_labels'},
#                                      keep_images_without_gt=False)

# Get the number of samples in the training and validations datasets.
train_dataset_size = train_dataset.get_dataset_size()
val_dataset_size = val_dataset.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size))
# Out:
# Number of images in the training dataset:	 10000
# Number of images in the validation dataset:	   479

# %%
num_epochss_real = 120
steps_per_G_epoch = 100
steps_per_D_epoch = 10
initial_epoch = 0
final_epoch = int(num_epochss_real * 370.0 / steps_per_G_epoch)
val_freq = int(final_epoch / num_epochss_real)

def lr_schedule(epoch):
    if epoch < 20:
        return 0.0005    
    elif epoch < int(0.7 * final_epoch):
        return 0.001
    elif epoch < int(0.9 * final_epoch):
        return 0.0001
    else:
        return 0.00001

# def lr_schedule(epoch):
#     if epoch < 20:
#         return 0.0005
#     elif epoch < 800:
#         return 0.001
#     elif epoch < 1000:
#         return 0.0001
#     else:
#         return 0.00001

# Define model callbacks.
# TODO: Set the filepath under which you want to save the model.
model_checkpoint = ModelCheckpoint(filepath=os.path.join(checkpoint_path, 'epoch-{epoch:02d}_loss-{loss:.4f}_val_loss-{val_loss:.4f}.h5'),
                                   monitor='val_loss',
                                   verbose=1,
                                   save_best_only=False,
                                   save_weights_only=True,
                                   mode='auto',
                                   period=1)

# model_checkpoint.best to the best validation loss from the previous training
# model_checkpoint.best = 4.83704

csv_logger = CSVLogger(filename=os.path.join(checkpoint_path, csv_file_name),
                       separator=',',
                       append=True)

learning_rate_scheduler = LearningRateScheduler(schedule=lr_schedule,
                                                verbose=1)

terminate_on_nan = TerminateOnNaN()

TensorBoard_monitor = TensorBoard(log_dir=checkpoint_path)

callbacks = [model_checkpoint,
             csv_logger,
             learning_rate_scheduler,
             terminate_on_nan,
             TensorBoard_monitor]

callbacks_no_val = [learning_rate_scheduler,
                    terminate_on_nan]

# def lr_schedule_D(epoch):
#     return 0.0005


# learning_rate_scheduler_D = LearningRateScheduler(schedule=lr_schedule_D,
#                                                   verbose=1)

# callbacks_no_val_D = [learning_rate_scheduler_D,
#                       terminate_on_nan]

# %%
for initial_epoch in range(final_epoch):
    try:
        print('\n')
        print('Train generator.')
        G_train_generator = train_dataset.generate(batch_size=batch_size,
                                                   generator_type='G',
                                                   shuffle=True,
                                                   transformations=[ssd_data_augmentation],
                                                   label_encoder=ssd_input_encoder,
                                                   returns={'processed_images',
                                                            'encoded_labels'},
                                                   keep_images_without_gt=False)  

        if initial_epoch != 0 and initial_epoch % val_freq == 0:
            val_generator = val_dataset.generate(batch_size=batch_size,
                                                 generator_type='G',
                                                 shuffle=False,
                                                 transformations=[convert_to_3_channels,
                                                                  resize],
                                                 label_encoder=ssd_input_encoder,
                                                 returns={'processed_images',
                                                          'encoded_labels'},
                                                 keep_images_without_gt=False)  

            history_G = G_model.fit_generator(generator=G_train_generator,
                                              steps_per_epoch=steps_per_G_epoch,
                                              epochs=initial_epoch+1,
                                              callbacks=callbacks,
                                              validation_data=val_generator,
                                              validation_steps=ceil(val_dataset_size/batch_size),
                                              initial_epoch=initial_epoch)

        else:
            history_G = G_model.fit_generator(generator=G_train_generator,
                                              steps_per_epoch=steps_per_G_epoch,
                                              epochs=initial_epoch+1,
                                              callbacks=callbacks_no_val,
                                              initial_epoch=initial_epoch)

        print('\n')
        print( 'Train discriminator.')
        D_train_generator = train_dataset.generate(batch_size=batch_size,
                                                   generator_type='D',
                                                   shuffle=True,
                                                   transformations=[ssd_data_augmentation],
                                                   label_encoder=ssd_input_encoder,
                                                   returns={'processed_images',
                                                            'encoded_labels'},
                                                   keep_images_without_gt=False)        

        history_D = D_model.fit_generator(generator=D_train_generator,
                                          steps_per_epoch=steps_per_D_epoch,
                                          epochs=initial_epoch+1,
                                          callbacks=callbacks_no_val,
                                          initial_epoch=initial_epoch)

    except ValueError:
        pass
# Out:
# Train generator.
# Epoch 1/1
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.0005.
# 100/100 [==============================] - 117s 1s/step - loss: 18.5668 - D_model_loss: 1.6367 - predictions_loss: 14.1449
#
#
# Train discriminator.
# /usr/local/lib/python3.5/dist-packages/keras/engine/training.py:490: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# Epoch 1/1
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.0005.
# 10/10 [==============================] - 8s 786ms/step - loss: 1.4076 - lambda_4_loss: 14.9622 - lambda_5_loss: 0.3021
#
#
# Train generator.
# Epoch 2/2
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0005.
# 100/100 [==============================] - 101s 1s/step - loss: 17.9046 - D_model_loss: 0.6447 - predictions_loss: 13.4857
#
#
# Train discriminator.
# Epoch 2/2
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0005.
# 10/10 [==============================] - 3s 318ms/step - loss: 1.4063 - lambda_4_loss: 15.0174 - lambda_5_loss: 1.1921e-07
#
#
# Train generator.
# Epoch 3/3
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.0005.
# 100/100 [==============================] - 102s 1s/step - loss: 13.1610 - D_model_loss: 0.0266 - predictions_loss: 8.7461
#
#
# Train discriminator.
# Epoch 3/3
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.0005.
# 10/10 [==============================] - 3s 345ms/step - loss: 1.4052 - lambda_4_loss: 15.9424 - lambda_5_loss: 1.1921e-07
#
#
# Train generator.
# Epoch 4/4
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.0005.
# 100/100 [==============================] - 128s 1s/step - loss: 11.5679 - D_model_loss: 7.6148e-07 - predictions_loss: 7.1568 - val_loss: 11.4749 - val_D_model_loss: 1.1921e-07 - val_predictions_loss: 7.0657
#
# Epoch 00004: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-04_loss-11.5626_val_loss-11.4749.h5
#
#
# Train discriminator.
# Epoch 4/4
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.0005.
# 10/10 [==============================] - 3s 339ms/step - loss: 1.4041 - lambda_4_loss: 15.9424 - lambda_5_loss: 1.1921e-07
#
#
# Train generator.
# Epoch 5/5
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.0005.
# 100/100 [==============================] - 102s 1s/step - loss: 10.6389 - D_model_loss: 1.2000e-07 - predictions_loss: 6.2317
#
#
# Train discriminator.
# Epoch 5/5
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.0005.
# 10/10 [==============================] - 4s 356ms/step - loss: 1.4028 - lambda_4_loss: 15.9424 - lambda_5_loss: 1.1921e-07
#
#
# Train generator.
# Epoch 6/6
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.0005.
# 100/100 [==============================] - 102s 1s/step - loss: 10.7065 - D_model_loss: 1.1921e-07 - predictions_loss: 6.3033
#
#
# Train discriminator.
# Epoch 6/6
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.0005.
# 10/10 [==============================] - 3s 341ms/step - loss: 1.4017 - lambda_4_loss: 15.9424 - lambda_5_loss: 1.1921e-07
#
#
# Train generator.
# Epoch 7/7
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.0005.
# 100/100 [==============================] - 128s 1s/step - loss: 10.0687 - D_model_loss: 2.8294e-07 - predictions_loss: 5.6695 - val_loss: 10.1249 - val_D_model_loss: 1.1921e-07 - val_predictions_loss: 5.7277
#
# Epoch 00007: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-07_loss-10.0685_val_loss-10.1249.h5
#
#
# Train discriminator.
# Epoch 7/7
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.0005.
# 10/10 [==============================] - 4s 396ms/step - loss: 1.4004 - lambda_4_loss: 15.9424 - lambda_5_loss: 1.1921e-07
#
#
# Train generator.
# Epoch 8/8
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.0005.
# 100/100 [==============================] - 101s 1s/step - loss: 9.8686 - D_model_loss: 1.1921e-07 - predictions_loss: 5.4734
#
#
# Train discriminator.
# Epoch 8/8
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.0005.
# 10/10 [==============================] - 4s 361ms/step - loss: 1.3992 - lambda_4_loss: 15.9424 - lambda_5_loss: 1.1921e-07
#
#
# Train generator.
# Epoch 9/9
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.0005.
# 100/100 [==============================] - 102s 1s/step - loss: 9.9703 - D_model_loss: 1.2179e-07 - predictions_loss: 5.5790
#
#
# Train discriminator.
# Epoch 9/9
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.0005.
# 10/10 [==============================] - 4s 371ms/step - loss: 1.3980 - lambda_4_loss: 15.9424 - lambda_5_loss: 1.1921e-07
#
#
# Train generator.
# Epoch 10/10
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.0005.
# 100/100 [==============================] - 128s 1s/step - loss: 9.6604 - D_model_loss: 1.1921e-07 - predictions_loss: 5.2731 - val_loss: 10.1326 - val_D_model_loss: 1.1921e-07 - val_predictions_loss: 5.7474
#
# Epoch 00010: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-10_loss-9.6604_val_loss-10.1326.h5
#
#
# Train discriminator.
# Epoch 10/10
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.0005.
# 10/10 [==============================] - 4s 374ms/step - loss: 1.3968 - lambda_4_loss: 15.9424 - lambda_5_loss: 1.1921e-07
#
#
# Train generator.
# Epoch 11/11
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.0005.
# 100/100 [==============================] - 102s 1s/step - loss: 9.5912 - D_model_loss: 0.0269 - predictions_loss: 5.2080
#
#
# Train discriminator.
# Epoch 11/11
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.0005.
# 10/10 [==============================] - 4s 389ms/step - loss: 1.3956 - lambda_4_loss: 15.9424 - lambda_5_loss: 1.1921e-07
#
#
# Train generator.
# Epoch 12/12
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.0005.
# 100/100 [==============================] - 102s 1s/step - loss: 9.5199 - D_model_loss: 0.0122 - predictions_loss: 5.1407
#
#
# Train discriminator.
# Epoch 12/12
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.0005.
# 10/10 [==============================] - 4s 381ms/step - loss: 1.3944 - lambda_4_loss: 15.9424 - lambda_5_loss: 1.1921e-07
#
#
# Train generator.
# Epoch 13/13
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.0005.
# 100/100 [==============================] - 132s 1s/step - loss: 9.4983 - D_model_loss: 1.7354e-05 - predictions_loss: 5.1231 - val_loss: 9.9320 - val_D_model_loss: 1.1921e-07 - val_predictions_loss: 5.5587
#
# Epoch 00013: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-13_loss-9.4974_val_loss-9.9320.h5
#
#
# Train discriminator.
# Epoch 13/13
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.0005.
# 10/10 [==============================] - 4s 425ms/step - loss: 1.3932 - lambda_4_loss: 15.9424 - lambda_5_loss: 1.1921e-07
#
#
# Train generator.
# Epoch 14/14
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.0005.
# 100/100 [==============================] - 101s 1s/step - loss: 9.2925 - D_model_loss: 1.7882e-07 - predictions_loss: 4.9213
#
#
# Train discriminator.
# Epoch 14/14
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.0005.
# 10/10 [==============================] - 3s 344ms/step - loss: 1.3920 - lambda_4_loss: 15.9424 - lambda_5_loss: 1.1921e-07
#
#
# Train generator.
# Epoch 15/15
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.0005.
# 100/100 [==============================] - 102s 1s/step - loss: 9.2477 - D_model_loss: 4.2491e-07 - predictions_loss: 4.8804
#
#
# Train discriminator.
# Epoch 15/15
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.0005.
# 10/10 [==============================] - 4s 360ms/step - loss: 1.3908 - lambda_4_loss: 15.9424 - lambda_5_loss: 1.1921e-07
#
#
# Train generator.
# Epoch 16/16
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.0005.
# 100/100 [==============================] - 131s 1s/step - loss: 9.1989 - D_model_loss: 1.1921e-07 - predictions_loss: 4.8356 - val_loss: 10.3859 - val_D_model_loss: 1.1921e-07 - val_predictions_loss: 6.0246
#
# Epoch 00016: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-16_loss-9.1973_val_loss-10.3859.h5
#
#
# Train discriminator.
# Epoch 16/16
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.0005.
# 10/10 [==============================] - 4s 373ms/step - loss: 1.3896 - lambda_4_loss: 15.9424 - lambda_5_loss: 1.1921e-07
#
#
# Train generator.
# Epoch 17/17
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.0005.
#
#
# Train generator.
# Epoch 18/18
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.0005.
# 100/100 [==============================] - 102s 1s/step - loss: 9.0189 - D_model_loss: 0.0141 - predictions_loss: 4.6597
#
#
# Train discriminator.
# Epoch 18/18
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.0005.
# 10/10 [==============================] - 4s 368ms/step - loss: 1.3884 - lambda_4_loss: 15.9424 - lambda_5_loss: 1.1921e-07
#
#
# Train generator.
# Epoch 19/19
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.0005.
# 100/100 [==============================] - 140s 1s/step - loss: 9.1251 - D_model_loss: 1.8060e-07 - predictions_loss: 4.7699 - val_loss: 9.7491 - val_D_model_loss: 1.1921e-07 - val_predictions_loss: 5.3959
#
# Epoch 00019: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-19_loss-9.1251_val_loss-9.7491.h5
#
#
# Train discriminator.
# Epoch 19/19
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.0005.
# 10/10 [==============================] - 3s 341ms/step - loss: 1.3872 - lambda_4_loss: 15.9424 - lambda_5_loss: 1.1921e-07
#
#
# Train generator.
# Epoch 20/20
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.0005.
# 100/100 [==============================] - 103s 1s/step - loss: 9.0390 - D_model_loss: 1.6809e-07 - predictions_loss: 4.6878
#
#
# Train discriminator.
# Epoch 20/20
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.0005.
# 10/10 [==============================] - 4s 364ms/step - loss: 1.3860 - lambda_4_loss: 15.9424 - lambda_5_loss: 1.1921e-07
#
#
# Train generator.
# Epoch 21/21
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 102s 1s/step - loss: 10.2659 - D_model_loss: 3.1398e-06 - predictions_loss: 5.9200
#
#
# Train discriminator.
# Epoch 21/21
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 3s 318ms/step - loss: 1.3841 - lambda_4_loss: 15.9424 - lambda_5_loss: 1.1921e-07
#
#
# Train generator.
# Epoch 22/22
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 128s 1s/step - loss: 13.2754 - D_model_loss: 0.0147 - predictions_loss: 8.9330 - val_loss: 13.2348 - val_D_model_loss: 1.1921e-07 - val_predictions_loss: 8.8928
#
# Epoch 00022: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-22_loss-13.2756_val_loss-13.2348.h5
#
#
# Train discriminator.
# Epoch 22/22
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 366ms/step - loss: 1.3832 - lambda_4_loss: 15.0810 - lambda_5_loss: 1.1921e-07
#
#
# Train generator.
# Epoch 23/23
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 101s 1s/step - loss: 11.1134 - D_model_loss: 0.0375 - predictions_loss: 6.7735
#
#
# Train discriminator.
# Epoch 23/23
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 6s 625ms/step - loss: 1.3818 - lambda_4_loss: 15.9424 - lambda_5_loss: 1.1921e-07
#
#
# Train generator.
# Epoch 24/24
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 101s 1s/step - loss: 10.0288 - D_model_loss: 1.1921e-07 - predictions_loss: 5.6959
#
#
# Train discriminator.
# Epoch 24/24
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 375ms/step - loss: 1.3796 - lambda_4_loss: 15.9424 - lambda_5_loss: 1.1921e-07
#
#
# Train generator.
# Epoch 25/25
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 131s 1s/step - loss: 9.4816 - D_model_loss: 4.3228e-07 - predictions_loss: 5.1562 - val_loss: 10.7708 - val_D_model_loss: 1.1921e-07 - val_predictions_loss: 6.4492
#
# Epoch 00025: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-25_loss-9.4805_val_loss-10.7708.h5
#
#
# Train discriminator.
# Epoch 25/25
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 7s 686ms/step - loss: 1.3773 - lambda_4_loss: 15.9424 - lambda_5_loss: 1.1921e-07
#
#
# Train generator.
# Epoch 26/26
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 101s 1s/step - loss: 9.6355 - D_model_loss: 4.7539e-07 - predictions_loss: 5.3177
#
#
# Train discriminator.
# Epoch 26/26
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 7s 716ms/step - loss: 1.3751 - lambda_4_loss: 15.9424 - lambda_5_loss: 1.1921e-07
#
#
# Train generator.
# Epoch 27/27
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 101s 1s/step - loss: 9.4273 - D_model_loss: 1.1961e-07 - predictions_loss: 5.1172
#
#
# Train discriminator.
# Epoch 27/27
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 8s 801ms/step - loss: 1.3729 - lambda_4_loss: 15.9424 - lambda_5_loss: 1.1921e-07
#
#
# Train generator.
# Epoch 28/28
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 130s 1s/step - loss: 9.3050 - D_model_loss: 1.4822e-07 - predictions_loss: 5.0024 - val_loss: 10.1572 - val_D_model_loss: 1.1921e-07 - val_predictions_loss: 5.8585
#
# Epoch 00028: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-28_loss-9.3070_val_loss-10.1572.h5
#
#
# Train discriminator.
# Epoch 28/28
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 355ms/step - loss: 1.3706 - lambda_4_loss: 15.9424 - lambda_5_loss: 1.1921e-07
#
#
# Train generator.
# Epoch 29/29
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 102s 1s/step - loss: 9.2699 - D_model_loss: 3.0437e-06 - predictions_loss: 4.9751
#
#
# Train discriminator.
# Epoch 29/29
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 369ms/step - loss: 1.3684 - lambda_4_loss: 15.9424 - lambda_5_loss: 1.1921e-07
#
#
# Train generator.
# Epoch 30/30
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 102s 1s/step - loss: 9.4037 - D_model_loss: 3.4334e-07 - predictions_loss: 5.1164
#
#
# Train discriminator.
# Epoch 30/30
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 5s 452ms/step - loss: 1.3662 - lambda_4_loss: 15.9424 - lambda_5_loss: 1.1921e-07
#
#
# Train generator.
# Epoch 31/31
#
# Epoch 00031: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 135s 1s/step - loss: 9.2294 - D_model_loss: 3.7027e-07 - predictions_loss: 4.9497 - val_loss: 9.8875 - val_D_model_loss: 1.1921e-07 - val_predictions_loss: 5.6117
#
# Epoch 00031: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-31_loss-9.2293_val_loss-9.8875.h5
#
#
# Train discriminator.
# Epoch 31/31
#
# Epoch 00031: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 354ms/step - loss: 1.3640 - lambda_4_loss: 15.9424 - lambda_5_loss: 1.2120e-07
#
#
# Train generator.
# Epoch 32/32
#
# Epoch 00032: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 101s 1s/step - loss: 9.1478 - D_model_loss: 4.9630e-05 - predictions_loss: 4.8757
#
#
# Train discriminator.
# Epoch 32/32
#
# Epoch 00032: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 407ms/step - loss: 1.3618 - lambda_4_loss: 15.9040 - lambda_5_loss: 1.6093e-07
#
#
# Train generator.
# Epoch 33/33
#
# Epoch 00033: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 102s 1s/step - loss: 9.1911 - D_model_loss: 1.2636e-06 - predictions_loss: 4.9266
#
#
# Train discriminator.
# Epoch 33/33
#
# Epoch 00033: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 393ms/step - loss: 1.3596 - lambda_4_loss: 15.8197 - lambda_5_loss: 2.7816e-07
#
#
# Train generator.
# Epoch 34/34
#
# Epoch 00034: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 131s 1s/step - loss: 8.9548 - D_model_loss: 1.3431e-07 - predictions_loss: 4.6980 - val_loss: 9.5028 - val_D_model_loss: 1.1921e-07 - val_predictions_loss: 5.2498
#
# Epoch 00034: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-34_loss-8.9560_val_loss-9.5028.h5
#
#
# Train discriminator.
# Epoch 34/34
#
# Epoch 00034: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 354ms/step - loss: 1.3574 - lambda_4_loss: 15.9424 - lambda_5_loss: 1.1921e-07
#
#
# Train generator.
# Epoch 35/35
#
# Epoch 00035: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 101s 1s/step - loss: 8.8556 - D_model_loss: 1.2279e-07 - predictions_loss: 4.6064
#
#
# Train discriminator.
# Epoch 35/35
#
# Epoch 00035: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 3s 347ms/step - loss: 1.3551 - lambda_4_loss: 15.8692 - lambda_5_loss: 4.2177e-06
#
#
# Train generator.
# Epoch 36/36
#
# Epoch 00036: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 104s 1s/step - loss: 8.9225 - D_model_loss: 1.1921e-07 - predictions_loss: 4.6810
#
#
# Train discriminator.
# Epoch 36/36
#
# Epoch 00036: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 380ms/step - loss: 1.3529 - lambda_4_loss: 15.9424 - lambda_5_loss: 2.3643e-07
#
#
# Train generator.
# Epoch 37/37
#
# Epoch 00037: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 128s 1s/step - loss: 8.9063 - D_model_loss: 1.2577e-07 - predictions_loss: 4.6723 - val_loss: 9.7870 - val_D_model_loss: 1.1921e-07 - val_predictions_loss: 5.5568
#
# Epoch 00037: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-37_loss-8.9050_val_loss-9.7870.h5
#
#
# Train discriminator.
# Epoch 37/37
#
# Epoch 00037: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 373ms/step - loss: 1.3507 - lambda_4_loss: 15.9424 - lambda_5_loss: 1.1921e-07
#
#
# Train generator.
# Epoch 38/38
#
# Epoch 00038: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 101s 1s/step - loss: 8.7352 - D_model_loss: 1.1941e-07 - predictions_loss: 4.5089
#
#
# Train discriminator.
# Epoch 38/38
#
# Epoch 00038: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 5s 459ms/step - loss: 1.3484 - lambda_4_loss: 15.8662 - lambda_5_loss: 1.9880e-07
#
#
# Train generator.
# Epoch 39/39
#
# Epoch 00039: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 102s 1s/step - loss: 8.6340 - D_model_loss: 3.3677e-07 - predictions_loss: 4.4155
#
#
# Train discriminator.
# Epoch 39/39
#
# Epoch 00039: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 356ms/step - loss: 1.3461 - lambda_4_loss: 15.9424 - lambda_5_loss: 1.1921e-07
#
#
# Train generator.
# Epoch 40/40
#
# Epoch 00040: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 134s 1s/step - loss: 8.9945 - D_model_loss: 5.9166e-06 - predictions_loss: 4.7836 - val_loss: 9.7056 - val_D_model_loss: 1.1921e-07 - val_predictions_loss: 5.4984
#
# Epoch 00040: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-40_loss-8.9930_val_loss-9.7056.h5
#
#
# Train discriminator.
# Epoch 40/40
#
# Epoch 00040: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 3s 348ms/step - loss: 1.3440 - lambda_4_loss: 15.9424 - lambda_5_loss: 1.1921e-07
#
#
# Train generator.
# Epoch 41/41
#
# Epoch 00041: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 102s 1s/step - loss: 8.6996 - D_model_loss: 3.4602e-06 - predictions_loss: 4.4961
#
#
# Train discriminator.
# Epoch 41/41
#
# Epoch 00041: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 385ms/step - loss: 1.3418 - lambda_4_loss: 15.6599 - lambda_5_loss: 7.1129e-07
#
#
# Train generator.
# Epoch 42/42
#
# Epoch 00042: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 103s 1s/step - loss: 9.1377 - D_model_loss: 9.0627e-05 - predictions_loss: 4.9417
#
#
# Train discriminator.
# Epoch 42/42
#
# Epoch 00042: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 397ms/step - loss: 1.3397 - lambda_4_loss: 15.9424 - lambda_5_loss: 1.1921e-07
#
#
# Train generator.
# Epoch 43/43
#
# Epoch 00043: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 191s 2s/step - loss: 8.5610 - D_model_loss: 1.3844e-06 - predictions_loss: 4.3725 - val_loss: 9.9188 - val_D_model_loss: 1.1921e-07 - val_predictions_loss: 5.7341
#
# Epoch 00043: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-43_loss-8.5603_val_loss-9.9188.h5
#
#
# Train discriminator.
# Epoch 43/43
#
# Epoch 00043: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 361ms/step - loss: 1.3374 - lambda_4_loss: 15.8925 - lambda_5_loss: 1.5696e-07
#
#
# Train generator.
# Epoch 44/44
#
# Epoch 00044: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 104s 1s/step - loss: 8.6551 - D_model_loss: 8.4306e-05 - predictions_loss: 4.4742
#
#
# Train discriminator.
# Epoch 44/44
#
# Epoch 00044: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 369ms/step - loss: 1.3352 - lambda_4_loss: 15.9424 - lambda_5_loss: 1.3510e-07
#
#
# Train generator.
# Epoch 45/45
#
# Epoch 00045: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 104s 1s/step - loss: 8.8064 - D_model_loss: 1.1483e-06 - predictions_loss: 4.6330
#
#
# Train discriminator.
# Epoch 45/45
#
# Epoch 00045: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 379ms/step - loss: 1.3330 - lambda_4_loss: 15.8510 - lambda_5_loss: 3.1245e-06
#
#
# Train generator.
# Epoch 46/46
#
# Epoch 00046: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 135s 1s/step - loss: 8.5997 - D_model_loss: 9.9220e-07 - predictions_loss: 4.4337 - val_loss: 9.4205 - val_D_model_loss: 1.1921e-07 - val_predictions_loss: 5.2583
#
# Epoch 00046: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-46_loss-8.6011_val_loss-9.4205.h5
#
#
# Train discriminator.
# Epoch 46/46
#
# Epoch 00046: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 384ms/step - loss: 1.3308 - lambda_4_loss: 15.7107 - lambda_5_loss: 2.0128e-06
#
#
# Train generator.
# Epoch 47/47
#
# Epoch 00047: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 102s 1s/step - loss: 8.4421 - D_model_loss: 1.2362e-05 - predictions_loss: 4.2837
#
#
# Train discriminator.
# Epoch 47/47
#
# Epoch 00047: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 391ms/step - loss: 1.3286 - lambda_4_loss: 15.8700 - lambda_5_loss: 2.6226e-07
#
#
# Train generator.
# Epoch 48/48
#
# Epoch 00048: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 102s 1s/step - loss: 8.5581 - D_model_loss: 1.7629e-06 - predictions_loss: 4.4072
#
#
# Train discriminator.
# Epoch 48/48
#
# Epoch 00048: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 379ms/step - loss: 1.3264 - lambda_4_loss: 15.7411 - lambda_5_loss: 3.0883e-04
#
#
# Train generator.
# Epoch 49/49
#
# Epoch 00049: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 130s 1s/step - loss: 8.4760 - D_model_loss: 2.7427e-07 - predictions_loss: 4.3327 - val_loss: 9.3565 - val_D_model_loss: 1.1921e-07 - val_predictions_loss: 5.2170
# Epoch 00049: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-49_loss-8.4775_val_loss-9.3565.h5
#
#
# Train discriminator.
# Epoch 49/49
#
# Epoch 00049: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 372ms/step - loss: 1.3242 - lambda_4_loss: 15.7672 - lambda_5_loss: 1.1710e-05
#
#
# Train generator.
# Epoch 50/50
#
# Epoch 00050: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 105s 1s/step - loss: 8.3291 - D_model_loss: 6.5794e-07 - predictions_loss: 4.1932
#
#
# Train discriminator.
# Epoch 50/50
#
# Epoch 00050: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 378ms/step - loss: 1.3220 - lambda_4_loss: 15.8090 - lambda_5_loss: 3.4087e-06
#
#
# Train generator.
# Epoch 51/51
#
# Epoch 00051: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 102s 1s/step - loss: 8.6581 - D_model_loss: 5.6636e-05 - predictions_loss: 4.5297
#
#
# Train discriminator.
# Epoch 51/51
#
# Epoch 00051: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 367ms/step - loss: 1.3199 - lambda_4_loss: 15.7822 - lambda_5_loss: 9.9330e-06
#
#
# Train generator.
# Epoch 52/52
#
# Epoch 00052: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 134s 1s/step - loss: 8.3341 - D_model_loss: 6.7369e-07 - predictions_loss: 4.2131 - val_loss: 9.7350 - val_D_model_loss: 1.1921e-07 - val_predictions_loss: 5.6179
#
# Epoch 00052: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-52_loss-8.3341_val_loss-9.7350.h5
#
#
# Train discriminator.
# Epoch 52/52
#
# Epoch 00052: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 420ms/step - loss: 1.3176 - lambda_4_loss: 15.8291 - lambda_5_loss: 1.0219e-05
#
#
# Train generator.
# Epoch 53/53
#
# Epoch 00053: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 103s 1s/step - loss: 8.3863 - D_model_loss: 4.1724e-05 - predictions_loss: 4.2729
#
#
# Train discriminator.
# Epoch 53/53
#
# Epoch 00053: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 381ms/step - loss: 1.3154 - lambda_4_loss: 15.9424 - lambda_5_loss: 1.7285e-07
#
#
# Train generator.
# Epoch 54/54
#
# Epoch 00054: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 102s 1s/step - loss: 8.2784 - D_model_loss: 2.2482e-05 - predictions_loss: 4.1725
#
#
# Train discriminator.
# Epoch 54/54
#
# Epoch 00054: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 360ms/step - loss: 1.3132 - lambda_4_loss: 15.7605 - lambda_5_loss: 1.9469e-04
#
#
# Train generator.
# Epoch 55/55
#
# Epoch 00055: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 135s 1s/step - loss: 8.3896 - D_model_loss: 3.3623e-05 - predictions_loss: 4.2913 - val_loss: 9.7635 - val_D_model_loss: 1.1921e-07 - val_predictions_loss: 5.6689
#
# Epoch 00055: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-55_loss-8.3896_val_loss-9.7635.h5
#
#
# Train discriminator.
# Epoch 55/55
#
# Epoch 00055: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 398ms/step - loss: 1.3110 - lambda_4_loss: 15.9424 - lambda_5_loss: 1.2914e-07
#
#
# Train generator.
# Epoch 56/56
#
# Epoch 00056: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 101s 1s/step - loss: 8.3012 - D_model_loss: 1.9173e-07 - predictions_loss: 4.2103
#
#
# Train discriminator.
# Epoch 56/56
#
# Epoch 00056: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 358ms/step - loss: 1.3088 - lambda_4_loss: 15.9424 - lambda_5_loss: 1.1921e-07
#
#
# Train generator.
# Epoch 57/57
#
# Epoch 00057: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 103s 1s/step - loss: 8.4338 - D_model_loss: 1.2515e-04 - predictions_loss: 4.3501
#
#
# Train discriminator.
# Epoch 57/57
#
# Epoch 00057: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 3s 333ms/step - loss: 1.3067 - lambda_4_loss: 15.8578 - lambda_5_loss: 1.1921e-07
#
#
# Train generator.
# Epoch 58/58
#
# Epoch 00058: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 190s 2s/step - loss: 8.3373 - D_model_loss: 8.1633e-05 - predictions_loss: 4.2608 - val_loss: 9.4529 - val_D_model_loss: 1.1921e-07 - val_predictions_loss: 5.3802
#
# Epoch 00058: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-58_loss-8.3372_val_loss-9.4529.h5
#
#
# Train discriminator.
# Epoch 58/58
#
# Epoch 00058: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 380ms/step - loss: 1.3046 - lambda_4_loss: 15.8785 - lambda_5_loss: 1.8289e-07
#
#
# Train generator.
# Epoch 59/59
#
# Epoch 00059: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 105s 1s/step - loss: 8.2925 - D_model_loss: 9.2535e-06 - predictions_loss: 4.2235
#
#
# Train discriminator.
# Epoch 59/59
#
# Epoch 00059: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 407ms/step - loss: 1.3024 - lambda_4_loss: 15.7068 - lambda_5_loss: 3.0453e-05
#
#
# Train generator.
# Epoch 60/60
#
# Epoch 00060: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 105s 1s/step - loss: 8.3021 - D_model_loss: 1.2998e-06 - predictions_loss: 4.2405
#
#
# Train discriminator.
# Epoch 60/60
#
# Epoch 00060: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 3s 349ms/step - loss: 1.3003 - lambda_4_loss: 15.9424 - lambda_5_loss: 1.1921e-07
#
#
# Train generator.
# Epoch 61/61
#
# Epoch 00061: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 130s 1s/step - loss: 8.5482 - D_model_loss: 2.6210e-05 - predictions_loss: 4.4937 - val_loss: 9.9980 - val_D_model_loss: 1.1921e-07 - val_predictions_loss: 5.9472
#
# Epoch 00061: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-61_loss-8.5486_val_loss-9.9980.h5
#
#
# Train discriminator.
# Epoch 61/61
#
# Epoch 00061: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 353ms/step - loss: 1.2982 - lambda_4_loss: 15.8698 - lambda_5_loss: 1.1921e-07
#
#
# Train generator.
# Epoch 62/62
#
# Epoch 00062: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 101s 1s/step - loss: 8.2215 - D_model_loss: 5.4260e-06 - predictions_loss: 4.1743
#
#
# Train discriminator.
# Epoch 62/62
#
# Epoch 00062: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 3s 348ms/step - loss: 1.2960 - lambda_4_loss: 15.8047 - lambda_5_loss: 1.7778e-05
#
#
# Train generator.
# Epoch 63/63
#
# Epoch 00063: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 101s 1s/step - loss: 8.3954 - D_model_loss: 7.4659e-06 - predictions_loss: 4.3555
#
#
# Train discriminator.
# Epoch 63/63
#
# Epoch 00063: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 361ms/step - loss: 1.2939 - lambda_4_loss: 15.4250 - lambda_5_loss: 1.7285e-07
#
#
# Train generator.
# Epoch 64/64
#
# Epoch 00064: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 129s 1s/step - loss: 8.2231 - D_model_loss: 7.4283e-05 - predictions_loss: 4.1904 - val_loss: 9.2298 - val_D_model_loss: 1.1921e-07 - val_predictions_loss: 5.2007
#
# Epoch 00064: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-64_loss-8.2246_val_loss-9.2298.h5
#
#
# Train discriminator.
# Epoch 64/64
#
# Epoch 00064: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 377ms/step - loss: 1.2919 - lambda_4_loss: 15.6489 - lambda_5_loss: 2.6188e-06
#
#
# Train generator.
# Epoch 65/65
#
# Epoch 00065: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 101s 1s/step - loss: 8.1910 - D_model_loss: 4.8473e-06 - predictions_loss: 4.1655
#
#
# Train discriminator.
# Epoch 65/65
#
# Epoch 00065: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 3s 344ms/step - loss: 1.2897 - lambda_4_loss: 15.9040 - lambda_5_loss: 1.6093e-07
#
#
# Train generator.
# Epoch 66/66
#
# Epoch 00066: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 102s 1s/step - loss: 8.1234 - D_model_loss: 1.6238e-05 - predictions_loss: 4.1052
#
#
# Train discriminator.
# Epoch 66/66
#
# Epoch 00066: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 361ms/step - loss: 1.2875 - lambda_4_loss: 15.3997 - lambda_5_loss: 2.8598e-05
#
#
# Train generator.
# Epoch 67/67
#
# Epoch 00067: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 128s 1s/step - loss: 8.2021 - D_model_loss: 3.7278e-05 - predictions_loss: 4.1913 - val_loss: 9.5768 - val_D_model_loss: 1.1921e-07 - val_predictions_loss: 5.5698
#
# Epoch 00067: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-67_loss-8.2019_val_loss-9.5768.h5
#
#
# Train discriminator.
# Epoch 67/67
#
# Epoch 00067: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 383ms/step - loss: 1.2852 - lambda_4_loss: 14.5568 - lambda_5_loss: 9.5543e-04
#
#
# Train generator.
# Epoch 68/68
#
# Epoch 00068: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 101s 1s/step - loss: 8.0715 - D_model_loss: 1.0220e-05 - predictions_loss: 4.0680
#
#
# Train discriminator.
# Epoch 68/68
#
# Epoch 00068: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 3s 349ms/step - loss: 1.2832 - lambda_4_loss: 15.3790 - lambda_5_loss: 6.2188e-07
#
#
# Train generator.
# Epoch 69/69
#
# Epoch 00069: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 101s 1s/step - loss: 8.2957 - D_model_loss: 5.9378e-05 - predictions_loss: 4.2994
#
#
# Train discriminator.
# Epoch 69/69
#
# Epoch 00069: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 360ms/step - loss: 1.2811 - lambda_4_loss: 15.6836 - lambda_5_loss: 2.6187e-06
#
#
# Train generator.
# Epoch 70/70
#
# Epoch 00070: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 130s 1s/step - loss: 8.0473 - D_model_loss: 2.3671e-05 - predictions_loss: 4.0583 - val_loss: 9.6403 - val_D_model_loss: 1.1921e-07 - val_predictions_loss: 5.6549
#
# Epoch 00070: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-70_loss-8.0489_val_loss-9.6403.h5
#
#
# Train discriminator.
# Epoch 70/70
#
# Epoch 00070: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 357ms/step - loss: 1.2790 - lambda_4_loss: 15.8051 - lambda_5_loss: 2.4041e-07
#
#
# Train generator.
# Epoch 71/71
#
# Epoch 00071: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 102s 1s/step - loss: 8.2980 - D_model_loss: 2.5851e-05 - predictions_loss: 4.3160
#
#
# Train discriminator.
# Epoch 71/71
#
# Epoch 00071: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 366ms/step - loss: 1.2769 - lambda_4_loss: 15.4449 - lambda_5_loss: 1.9272e-06
#
#
# Train generator.
# Epoch 72/72
#
# Epoch 00072: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 102s 1s/step - loss: 8.1931 - D_model_loss: 8.9726e-05 - predictions_loss: 4.2183
#
#
# Train discriminator.
# Epoch 72/72
#
# Epoch 00072: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 368ms/step - loss: 1.2748 - lambda_4_loss: 15.1171 - lambda_5_loss: 2.6618e-05
#
#
# Train generator.
# Epoch 73/73
#
# Epoch 00073: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 145s 1s/step - loss: 8.0850 - D_model_loss: 1.2154e-04 - predictions_loss: 4.1174 - val_loss: 8.9330 - val_D_model_loss: 1.1921e-07 - val_predictions_loss: 4.9690
#
# Epoch 00073: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-73_loss-8.0859_val_loss-8.9330.h5
#
#
# Train discriminator.
# Epoch 73/73
#
# Epoch 00073: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 375ms/step - loss: 1.2726 - lambda_4_loss: 15.0866 - lambda_5_loss: 7.0374e-05
#
#
# Train generator.
# Epoch 74/74
#
# Epoch 00074: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 101s 1s/step - loss: 7.8717 - D_model_loss: 1.4060e-04 - predictions_loss: 3.9114
#
#
# Train discriminator.
# Epoch 74/74
#
# Epoch 00074: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 353ms/step - loss: 1.2705 - lambda_4_loss: 14.9684 - lambda_5_loss: 6.2729e-06
#
#
# Train generator.
# Epoch 75/75
#
# Epoch 00075: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 102s 1s/step - loss: 8.1238 - D_model_loss: 1.8770e-04 - predictions_loss: 4.1706
#
#
# Train discriminator.
# Epoch 75/75
#
# Epoch 00075: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 383ms/step - loss: 1.2684 - lambda_4_loss: 15.7267 - lambda_5_loss: 2.4479e-06
#
#
# Train generator.
# Epoch 76/76
#
# Epoch 00076: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 129s 1s/step - loss: 8.1640 - D_model_loss: 1.2384e-04 - predictions_loss: 4.2180 - val_loss: 9.5150 - val_D_model_loss: 1.1921e-07 - val_predictions_loss: 5.5725
#
# Epoch 00076: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-76_loss-8.1613_val_loss-9.5150.h5
#
#
# Train discriminator.
# Epoch 76/76
#
# Epoch 00076: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 418ms/step - loss: 1.2664 - lambda_4_loss: 15.4575 - lambda_5_loss: 0.0010
#
#
# Train generator.
# Epoch 77/77
#
# Epoch 00077: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 101s 1s/step - loss: 8.1269 - D_model_loss: 3.2331e-04 - predictions_loss: 4.1880
#
#
# Train discriminator.
# Epoch 77/77
#
# Epoch 00077: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 374ms/step - loss: 1.2642 - lambda_4_loss: 15.0830 - lambda_5_loss: 4.4098e-05
#
#
# Train generator.
# Epoch 78/78
#
# Epoch 00078: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 101s 1s/step - loss: 7.9864 - D_model_loss: 1.4244e-05 - predictions_loss: 4.0546
#
#
# Train discriminator.
# Epoch 78/78
#
# Epoch 00078: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 388ms/step - loss: 1.2622 - lambda_4_loss: 15.4977 - lambda_5_loss: 3.1658e-05
#
#
# Train generator.
# Epoch 79/79
#
# Epoch 00079: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 129s 1s/step - loss: 8.2354 - D_model_loss: 1.2452e-04 - predictions_loss: 4.3106 - val_loss: 9.1984 - val_D_model_loss: 1.1921e-07 - val_predictions_loss: 5.2771
#
# Epoch 00079: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-79_loss-8.2333_val_loss-9.1984.h5
#
#
# Train discriminator.
# Epoch 79/79
#
# Epoch 00079: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 410ms/step - loss: 1.2602 - lambda_4_loss: 15.1720 - lambda_5_loss: 1.0778e-05
#
#
# Train generator.
# Epoch 80/80
#
# Epoch 00080: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 101s 1s/step - loss: 8.0006 - D_model_loss: 8.7789e-05 - predictions_loss: 4.0828
#
#
# Train discriminator.
# Epoch 80/80
#
# Epoch 00080: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 3s 345ms/step - loss: 1.2580 - lambda_4_loss: 15.2044 - lambda_5_loss: 1.2837e-05
#
#
# Train generator.
# Epoch 81/81
#
# Epoch 00081: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 103s 1s/step - loss: 7.9197 - D_model_loss: 1.9637e-04 - predictions_loss: 4.0091
#
#
# Train discriminator.
# Epoch 81/81
#
# Epoch 00081: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 384ms/step - loss: 1.2559 - lambda_4_loss: 14.8495 - lambda_5_loss: 3.4069e-05
#
#
# Train generator.
# Epoch 82/82
#
# Epoch 00082: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 130s 1s/step - loss: 8.0041 - D_model_loss: 4.9471e-04 - predictions_loss: 4.1006 - val_loss: 8.9992 - val_D_model_loss: 1.1921e-07 - val_predictions_loss: 5.0992
#
# Epoch 00082: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-82_loss-8.0027_val_loss-8.9992.h5
#
#
# Train discriminator.
# Epoch 82/82
#
# Epoch 00082: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 386ms/step - loss: 1.2538 - lambda_4_loss: 14.8943 - lambda_5_loss: 8.8800e-06
#
#
# Train generator.
# Epoch 83/83
#
# Epoch 00083: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 102s 1s/step - loss: 8.0396 - D_model_loss: 2.0846e-04 - predictions_loss: 4.1432
#
#
# Train discriminator.
# Epoch 83/83
#
# Epoch 00083: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 387ms/step - loss: 1.2518 - lambda_4_loss: 15.0181 - lambda_5_loss: 1.4778e-04
#
#
# Train generator.
# Epoch 84/84
#
# Epoch 00084: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 101s 1s/step - loss: 7.8820 - D_model_loss: 3.0007e-04 - predictions_loss: 3.9925
#
#
# Train discriminator.
# Epoch 84/84
#
# Epoch 00084: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 416ms/step - loss: 1.2497 - lambda_4_loss: 15.0750 - lambda_5_loss: 2.0061e-05
#
#
# Train generator.
# Epoch 85/85
#
# Epoch 00085: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 129s 1s/step - loss: 7.9308 - D_model_loss: 1.4764e-04 - predictions_loss: 4.0484 - val_loss: 9.5535 - val_D_model_loss: 1.1921e-07 - val_predictions_loss: 5.6746
#
# Epoch 00085: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-85_loss-7.9270_val_loss-9.5535.h5
#
#
# Train discriminator.
# Epoch 85/85
#
# Epoch 00085: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 379ms/step - loss: 1.2475 - lambda_4_loss: 14.6420 - lambda_5_loss: 0.0015
#
#
# Train generator.
# Epoch 86/86
#
# Epoch 00086: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 101s 1s/step - loss: 7.9903 - D_model_loss: 6.4396e-05 - predictions_loss: 4.1148
#
#
# Train discriminator.
# Epoch 86/86
#
# Epoch 00086: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 401ms/step - loss: 1.2455 - lambda_4_loss: 15.1753 - lambda_5_loss: 5.0194e-05
#
#
# Train generator.
# Epoch 87/87
#
# Epoch 00087: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 102s 1s/step - loss: 7.8287 - D_model_loss: 2.6763e-04 - predictions_loss: 3.9603
#
#
# Train discriminator.
# Epoch 87/87
#
# Epoch 00087: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 361ms/step - loss: 1.2435 - lambda_4_loss: 15.2127 - lambda_5_loss: 1.6892e-04
#
#
# Train generator.
# Epoch 88/88
#
# Epoch 00088: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 128s 1s/step - loss: 7.8672 - D_model_loss: 1.4795e-04 - predictions_loss: 4.0058 - val_loss: 9.4549 - val_D_model_loss: 1.1921e-07 - val_predictions_loss: 5.5970
#
# Epoch 00088: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-88_loss-7.8653_val_loss-9.4549.h5
#
#
# Train discriminator.
# Epoch 88/88
#
# Epoch 00088: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 372ms/step - loss: 1.2414 - lambda_4_loss: 15.1000 - lambda_5_loss: 6.1136e-05
#
#
# Train generator.
# Epoch 89/89
#
# Epoch 00089: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 102s 1s/step - loss: 7.7389 - D_model_loss: 1.8151e-04 - predictions_loss: 3.8846
#
#
# Train discriminator.
# Epoch 89/89
#
# Epoch 00089: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 371ms/step - loss: 1.2393 - lambda_4_loss: 15.0490 - lambda_5_loss: 1.3395e-05
#
#
# Train generator.
# Epoch 90/90
#
# Epoch 00090: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 101s 1s/step - loss: 7.7772 - D_model_loss: 9.8147e-05 - predictions_loss: 3.9300
#
#
# Train discriminator.
# Epoch 90/90
#
# Epoch 00090: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 371ms/step - loss: 1.2372 - lambda_4_loss: 15.1226 - lambda_5_loss: 4.2421e-06
#
#
# Train generator.
# Epoch 91/91
#
# Epoch 00091: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 135s 1s/step - loss: 7.9443 - D_model_loss: 8.7257e-04 - predictions_loss: 4.1040 - val_loss: 9.2686 - val_D_model_loss: 1.6019e-07 - val_predictions_loss: 5.4317
#
# Epoch 00091: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-91_loss-7.9441_val_loss-9.2686.h5
#
#
# Train discriminator.
# Epoch 91/91
#
# Epoch 00091: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 363ms/step - loss: 1.2350 - lambda_4_loss: 13.1760 - lambda_5_loss: 3.3483e-04
#
#
# Train generator.
# Epoch 92/92
#
# Epoch 00092: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 102s 1s/step - loss: 7.8626 - D_model_loss: 0.0019 - predictions_loss: 4.0291
#
#
# Train discriminator.
# Epoch 92/92
#
# Epoch 00092: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 3s 347ms/step - loss: 1.2328 - lambda_4_loss: 11.8713 - lambda_5_loss: 0.0011
#
#
# Train generator.
# Epoch 93/93
#
# Epoch 00093: LearningRateScheduler setting learning rate to 0.001.
# ...
#
#
# Train generator.
# Epoch 322/322
#
# Epoch 00322: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 132s 1s/step - loss: 5.8723 - D_model_loss: 1.1190 - predictions_loss: 3.2419 - val_loss: 7.2505 - val_D_model_loss: 0.9215 - val_predictions_loss: 4.6204
# Epoch 00322: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-322_loss-5.8665_val_loss-7.2505.h5
#
#
# Train discriminator.
# Epoch 322/322
#
# Epoch 00322: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 4s 363ms/step - loss: 0.8795 - lambda_4_loss: 0.5314 - lambda_5_loss: 0.8638
#
#
# Train generator.
# Epoch 323/323
#
# Epoch 00323: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 102s 1s/step - loss: 5.8460 - D_model_loss: 1.1032 - predictions_loss: 3.2161
#
#
# Train discriminator.
# Epoch 323/323
#
# Epoch 00323: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 4s 379ms/step - loss: 0.8794 - lambda_4_loss: 0.4745 - lambda_5_loss: 0.9155
#
#
# Train generator.
# Epoch 324/324
#
# Epoch 00324: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 102s 1s/step - loss: 5.9445 - D_model_loss: 1.1492 - predictions_loss: 3.3151
#
#
# Train discriminator.
# Epoch 324/324
#
# Epoch 00324: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 4s 407ms/step - loss: 0.8792 - lambda_4_loss: 0.4402 - lambda_5_loss: 1.0809
#
#
# Train generator.
# Epoch 325/325
#
# Epoch 00325: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 131s 1s/step - loss: 5.8914 - D_model_loss: 1.2269 - predictions_loss: 3.2625 - val_loss: 7.2824 - val_D_model_loss: 1.1408 - val_predictions_loss: 4.6538
#
# Epoch 00325: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-325_loss-5.8914_val_loss-7.2824.h5
#
#
# Train discriminator.
# Epoch 325/325
#
# Epoch 00325: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 4s 376ms/step - loss: 0.8790 - lambda_4_loss: 0.4447 - lambda_5_loss: 1.0113
#
#
# Train generator.
# Epoch 326/326
#
# Epoch 00326: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 102s 1s/step - loss: 5.9563 - D_model_loss: 1.2646 - predictions_loss: 3.3280
#
#
# Train discriminator.
# Epoch 326/326
#
# Epoch 00326: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 4s 383ms/step - loss: 0.8789 - lambda_4_loss: 0.3943 - lambda_5_loss: 1.0364
#
#
# Train generator.
# Epoch 327/327
#
# Epoch 00327: LearningRateScheduler setting learning rate to 0.0001.
#
#
# Train generator.
# Epoch 328/328
#
# Epoch 00328: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 135s 1s/step - loss: 5.8476 - D_model_loss: 1.2519 - predictions_loss: 3.2197 - val_loss: 7.2677 - val_D_model_loss: 1.0528 - val_predictions_loss: 4.6401
#
# Epoch 00328: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-328_loss-5.8488_val_loss-7.2677.h5
#
#
# Train discriminator.
# Epoch 328/328
#
# Epoch 00328: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 3s 334ms/step - loss: 0.8787 - lambda_4_loss: 0.4284 - lambda_5_loss: 0.9231
#
#
# Train generator.
# Epoch 329/329
#
# Epoch 00329: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 102s 1s/step - loss: 5.8183 - D_model_loss: 1.1953 - predictions_loss: 3.1910
#
#
# Train discriminator.
# Epoch 329/329
#
# Epoch 00329: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 4s 351ms/step - loss: 0.8786 - lambda_4_loss: 0.4994 - lambda_5_loss: 0.8784
#
#
# Train generator.
# Epoch 330/330
#
# Epoch 00330: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 102s 1s/step - loss: 5.9609 - D_model_loss: 1.1742 - predictions_loss: 3.3341
#
#
# Train discriminator.
# Epoch 330/330
#
# Epoch 00330: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 4s 394ms/step - loss: 0.8784 - lambda_4_loss: 0.4217 - lambda_5_loss: 0.9573
#
#
# Train generator.
# Epoch 331/331
#
# Epoch 00331: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 131s 1s/step - loss: 5.8197 - D_model_loss: 1.0997 - predictions_loss: 3.1934 - val_loss: 7.1997 - val_D_model_loss: 0.8641 - val_predictions_loss: 4.5736
#
# Epoch 00331: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-331_loss-5.8197_val_loss-7.1997.h5
#
#
# Train discriminator.
# Epoch 331/331
#
# Epoch 00331: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 4s 372ms/step - loss: 0.8783 - lambda_4_loss: 0.5937 - lambda_5_loss: 0.8735
#
#
# Train generator.
# Epoch 332/332
#
# Epoch 00332: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 102s 1s/step - loss: 5.8305 - D_model_loss: 0.9898 - predictions_loss: 3.2047
#
#
# Train discriminator.
# Epoch 332/332
#
# Epoch 00332: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 4s 355ms/step - loss: 0.8781 - lambda_4_loss: 0.5020 - lambda_5_loss: 0.8782
#
#
# Train generator.
# Epoch 333/333
#
# Epoch 00333: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 102s 1s/step - loss: 5.9164 - D_model_loss: 1.0410 - predictions_loss: 3.2911
#
#
# Train discriminator.
# Epoch 333/333
#
# Epoch 00333: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 3s 338ms/step - loss: 0.8779 - lambda_4_loss: 0.5496 - lambda_5_loss: 0.8019
#
#
# Train generator.
# Epoch 334/334
#
# Epoch 00334: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 130s 1s/step - loss: 5.8226 - D_model_loss: 1.0602 - predictions_loss: 3.1978 - val_loss: 7.2147 - val_D_model_loss: 0.9559 - val_predictions_loss: 4.5902
#
# Epoch 00334: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-334_loss-5.8223_val_loss-7.2147.h5
#
#
# Train discriminator.
# Epoch 334/334
#
# Epoch 00334: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 4s 353ms/step - loss: 0.8778 - lambda_4_loss: 0.5154 - lambda_5_loss: 0.9274
#
#
# Train generator.
# Epoch 335/335
#
# Epoch 00335: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 102s 1s/step - loss: 5.9056 - D_model_loss: 1.0758 - predictions_loss: 3.2813
#
#
# Train discriminator.
# Epoch 335/335
#
# Epoch 00335: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 4s 352ms/step - loss: 0.8776 - lambda_4_loss: 0.5036 - lambda_5_loss: 0.9463
#
#
# Train generator.
# Epoch 336/336
#
# Epoch 00336: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 102s 1s/step - loss: 6.0069 - D_model_loss: 1.0315 - predictions_loss: 3.3831
#
#
# Train discriminator.
# Epoch 336/336
#
# Epoch 00336: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 3s 335ms/step - loss: 0.8775 - lambda_4_loss: 0.5514 - lambda_5_loss: 0.8725
#
#
# Train generator.
# Epoch 337/337
#
# Epoch 00337: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 173s 2s/step - loss: 5.9015 - D_model_loss: 1.0801 - predictions_loss: 3.2782 - val_loss: 7.2790 - val_D_model_loss: 1.0345 - val_predictions_loss: 4.6560
#
# Epoch 00337: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-337_loss-5.9016_val_loss-7.2790.h5
#
#
# Train discriminator.
# Epoch 337/337
#
# Epoch 00337: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 4s 363ms/step - loss: 0.8773 - lambda_4_loss: 0.4955 - lambda_5_loss: 0.9319
#
#
# Train generator.
# Epoch 338/338
#
# Epoch 00338: LearningRateScheduler setting learning rate to 0.0001.
#
#
# Train generator.
# Epoch 339/339
#
# Epoch 00339: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 101s 1s/step - loss: 5.8767 - D_model_loss: 1.1021 - predictions_loss: 3.2539
#
#
# Train discriminator.
# Epoch 339/339
#
# Epoch 00339: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 3s 335ms/step - loss: 0.8772 - lambda_4_loss: 0.5135 - lambda_5_loss: 0.8950
#
#
# Train generator.
# Epoch 340/340
#
# Epoch 00340: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 128s 1s/step - loss: 5.9914 - D_model_loss: 1.0097 - predictions_loss: 3.3691 - val_loss: 7.2334 - val_D_model_loss: 0.9497 - val_predictions_loss: 4.6114
#
# Epoch 00340: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-340_loss-5.9898_val_loss-7.2334.h5
#
#
# Train discriminator.
# Epoch 340/340
#
# Epoch 00340: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 4s 358ms/step - loss: 0.8770 - lambda_4_loss: 0.5093 - lambda_5_loss: 0.9328
#
#
# Train generator.
# Epoch 341/341
#
# Epoch 00341: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 102s 1s/step - loss: 5.9649 - D_model_loss: 1.0435 - predictions_loss: 3.3432
#
#
# Train discriminator.
# Epoch 341/341
#
# Epoch 00341: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 4s 368ms/step - loss: 0.8768 - lambda_4_loss: 0.4785 - lambda_5_loss: 0.9587
#
#
# Train generator.
# Epoch 342/342
#
# Epoch 00342: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 102s 1s/step - loss: 5.9785 - D_model_loss: 1.0825 - predictions_loss: 3.3572
#
#
# Train discriminator.
# Epoch 342/342
#
# Epoch 00342: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 4s 386ms/step - loss: 0.8767 - lambda_4_loss: 0.4377 - lambda_5_loss: 0.9933
#
#
# Train generator.
# Epoch 343/343
#
# Epoch 00343: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 131s 1s/step - loss: 5.8182 - D_model_loss: 1.0881 - predictions_loss: 3.1974 - val_loss: 7.1781 - val_D_model_loss: 1.0117 - val_predictions_loss: 4.5576
#
# Epoch 00343: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-343_loss-5.8181_val_loss-7.1781.h5
#
#
# Train discriminator.
# Epoch 343/343
#
# Epoch 00343: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 4s 367ms/step - loss: 0.8765 - lambda_4_loss: 0.4481 - lambda_5_loss: 0.9907
#
#
# Train generator.
# Epoch 344/344
#
# Epoch 00344: LearningRateScheduler setting learning rate to 0.0001.
#   3/100 [..............................] - ETA: 1:53 - loss: 5.7513 - D_model_loss: 1.1580 - predictions_loss: 3.1308
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-3688c189f5db> in <module>()
#      36                                               epochs=initial_epoch+1,
#      37                                               callbacks=callbacks_no_val,
# ---> 38                                               initial_epoch=initial_epoch)
#      39
#      40         print('\n')
#
# /usr/local/lib/python3.5/dist-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1416             use_multiprocessing=use_multiprocessing,
#    1417             shuffle=shuffle,
# -> 1418             initial_epoch=initial_epoch)
#    1419
#    1420     @interfaces.legacy_generator_methods_support
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     215                 outs = model.train_on_batch(x, y,
#     216                                             sample_weight=sample_weight,
# --> 217                                             class_weight=class_weight)
#     218
#     219                 outs = to_list(outs)
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1215             ins = x + y + sample_weights
#    1216         self._make_train_function()
# -> 1217         outputs = self.train_function(ins)
#    1218         return unpack_singleton(outputs)
#    1219
#
# /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2719                     'In order to feed symbolic tensors to a Keras model '
#    2720                     'in TensorFlow, you need tensorflow 1.8 or higher.')
# -> 2721             return self._legacy_call(inputs)
#    2722
#    2723
#
# /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py in _legacy_call(self, inputs)
#    2691         session = get_session()
#    2692         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2693                               **self.session_kwargs)
#    2694         return updated[:len(self.outputs)]
#    2695
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1126     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1127       results = self._do_run(handle, final_targets, final_fetches,
# -> 1128                              feed_dict_tensor, options, run_metadata)
#    1129     else:
#    1130       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1342     if handle is None:
#    1343       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1344                            options, run_metadata)
#    1345     else:
#    1346       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1348   def _do_call(self, fn, *args):
#    1349     try:
# -> 1350       return fn(*args)
#    1351     except errors.OpError as e:
#    1352       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1327           return tf_session.TF_Run(session, options,
#    1328                                    feed_dict, fetch_list, target_list,
# -> 1329                                    status, run_metadata)
#    1330
#    1331     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
# 1: Set the generator for the val_dataset or train_dataset predictions.

predict_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=None,
                                         returns={'processed_images',
                                                  'filenames',
                                                  'inverse_transform',
                                                  'original_images',
                                                  'original_labels'},
                                         keep_images_without_gt=False)

# 2: Generate samples.

batch_images, batch_filenames, batch_inverse_transforms, batch_original_images, batch_original_labels = next(predict_generator)

# %%
batch_images, batch_filenames, batch_inverse_transforms, batch_original_images, batch_original_labels = next(predict_generator)

# %%
i = 1
print("Image:", batch_filenames[i])
colors = plt.cm.hsv(np.linspace(0, 1, n_classes+1)).tolist()

plt.figure(figsize=(20, 12))
plt.imshow(batch_images[0][i])
plt.show()
plt.figure(figsize=(20, 12))
plt.imshow(batch_images[1][i])
plt.show()

# %%
i = 0  # Which batch item to look at

print("Image:", batch_filenames[i])
print()
print("Ground truth boxes:\n")
print(np.array(batch_original_labels[i]))

# 3: Make predictions.

y_pred = model.predict(batch_images)[-1]

# Now let's decode the raw predictions in `y_pred`.

# Had we created the model in 'inference' or 'inference_fast' mode,
# then the model's final layer would be a `DecodeDetections` layer and
# `y_pred` would already contain the decoded predictions,
# but since we created the model in 'training' mode,
# the model outputs raw predictions that still need to be decoded and filtered.
# This is what the `decode_detections()` function is for.
# It does exactly what the `DecodeDetections` layer would do,
# but using Numpy instead of TensorFlow (i.e. on the CPU instead of the GPU).

# `decode_detections()` with default argument values follows the procedure of the original SSD implementation:
# First, a very low confidence threshold of 0.01 is applied to filter out the majority of the predicted boxes,
# then greedy non-maximum suppression is performed per class with an intersection-over-union threshold of 0.45,
# and out of what is left after that, the top 200 highest confidence boxes are returned.
# Those settings are for precision-recall scoring purposes though.
# In order to get some usable final predictions, we'll set the confidence threshold much higher, e.g. to 0.5,
# since we're only interested in the very confident predictions.

# 4: Decode the raw predictions in `y_pred`.

y_pred_decoded = decode_detections(y_pred,
                                   confidence_thresh=0.35,
                                   iou_threshold=0.4,
                                   top_k=200,
                                   normalize_coords=normalize_coords,
                                   img_height=img_height,
                                   img_width=img_width)

# We made the predictions on the resized images,
# but we'd like to visualize the outcome on the original input images,
# so we'll convert the coordinates accordingly.
# Don't worry about that opaque `apply_inverse_transforms()` function below,
# in this simple case it just applies `(* original_image_size / resized_image_size)` to the box coordinates.

# 5: Convert the predictions for the original image.

y_pred_decoded_inv = apply_inverse_transforms(y_pred_decoded, batch_inverse_transforms)

np.set_printoptions(precision=2, suppress=True, linewidth=90)
print("Predicted boxes:\n")
print('   class   conf xmin   ymin   xmax   ymax')
print(y_pred_decoded_inv[i])

# Finally, let's draw the predicted boxes onto the image.
# Each predicted box says its confidence next to the category name.
# The ground truth boxes are also drawn onto the image in green for comparison.

# 5: Draw the predicted boxes onto the image

# Set the colors for the bounding boxes
colors = plt.cm.hsv(np.linspace(0, 1, n_classes+1)).tolist()

plt.figure(figsize=(20, 12))
plt.imshow(batch_original_images[i])

current_axis = plt.gca()

for box in batch_original_labels[i]:
    xmin = box[1]
    ymin = box[2]
    xmax = box[3]
    ymax = box[4]
    label = '{}'.format(classes[int(box[0])])
    current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color='green', fill=False, linewidth=2))
    current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor': 'green', 'alpha': 1.0})

# for box in y_pred_decoded_inv[i]:
#     xmin = box[2]
#     ymin = box[3]
#     xmax = box[4]
#     ymax = box[5]
#     color = colors[int(box[0])]
#     label = '{}: {:.2f}'.format(classes[int(box[0])], box[1])
#     current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color=color, fill=False, linewidth=2))
#     current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor': color, 'alpha': 1.0})
