# %%
import sys

sys.path.append('../')
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "1"
import glob

from keras.optimizers import Adam, SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TerminateOnNaN, CSVLogger, TensorBoard
from keras import backend as K
from keras.models import load_model
from math import ceil
import numpy as np
from matplotlib import pyplot as plt

from models.keras_ssd512_Siamese import ssd_512
from keras_loss_function.keras_ssd_loss import SSDLoss
from keras_layers.keras_layer_AnchorBoxes import AnchorBoxes
from keras_layers.keras_layer_DecodeDetections import DecodeDetections
from keras_layers.keras_layer_DecodeDetectionsFast import DecodeDetectionsFast
from keras_layers.keras_layer_L2Normalization import L2Normalization

from ssd_encoder_decoder.ssd_input_encoder import SSDInputEncoder
from ssd_encoder_decoder.ssd_output_decoder import decode_detections, decode_detections_fast

from data_generator.object_detection_2d_data_generator import DataGenerator
from data_generator.object_detection_2d_geometric_ops import Resize
from data_generator.object_detection_2d_photometric_ops import ConvertTo3Channels
from data_generator.data_augmentation_chain_original_ssd import SSDDataAugmentation, SSDDataAugmentation_Siamese
from data_generator.object_detection_2d_misc_utils import apply_inverse_transforms

img_height = 512  # Height of the model input images
img_width = 512  # Width of the model input images
img_channels = 3  # Number of color channels of the model input images
mean_color = [123, 117, 104]  # Per-channel mean of images. Do not change if use any of the pre-trained weights.
# The color channel order in the original SSD is BGR,
# so we'll have the model reverse the color channel order of the input images.
swap_channels = [2, 1, 0]
# The anchor box scaling factors used in the original SSD512 for the Pascal VOC datasets
# scales_pascal =
# The anchor box scaling factors used in the original SSD512 for the MS COCO datasets
scales_coco = [0.07, 0.15, 0.3, 0.45, 0.6, 0.75, 0.9, 1.05]
scales = scales_coco
aspect_ratios = [[1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5, 3.0, 1.0 / 3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0 / 3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0 / 3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0 / 3.0],
                 [1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5]]  # The anchor box aspect ratios used in the original SSD512; the order matters
two_boxes_for_ar1 = True
steps = [8, 16, 32, 64, 128, 256, 512]  # Space between two adjacent anchor box center points for each predictor layer.
# The offsets of the first anchor box center points from the top and left borders of the image
# as a fraction of the step size for each predictor layer.
offsets = [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
clip_boxes = False  # Whether or not to clip the anchor boxes to lie entirely within the image boundaries
# The variances by which the encoded target coordinates are divided as in the original implementation
variances = [0.1, 0.1, 0.2, 0.2]
normalize_coords = True
Model_Build = 'New_Model'  # 'Load_Model'
Optimizer_Type = 'SGD'  # 'Adam'  #
# Different batch_size will have different prediction loss.
batch_size = 6  # Change the batch size if you like, or if you run into GPU memory issues.
# alpha_distance = 0.0001  # Coefficient for the distance between the source and target feature maps.
G_loss_weights = [0.0001, 1.0]
D_loss_weights = [0.0001, 0.0001]

# 'City_to_foggy0_01_resize_600_1200' # 'City_to_foggy0_02_resize_600_1200'  # 'SIM10K_to_VOC07'
# 'SIM10K'  # 'Cityscapes_foggy_beta_0_01'  #  'City_to_foggy0_02_resize_400_800'
# 'SIM10K_to_VOC12_resize_400_800'
DatasetName = 'SIM10K_to_City_resize_400_800' # 'SIM10K_to_VOC07_resize_400_800'  # 'City_to_foggy0_01_resize_400_800'  # 
processed_dataset_path = './processed_dataset_h5/' + DatasetName
if not os.path.exists(processed_dataset_path):
    os.makedirs(processed_dataset_path)

checkpoint_path = '../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001'
if not os.path.exists(checkpoint_path):
    os.makedirs(checkpoint_path)
    
csv_file_name = 'training_log.csv'    
    
if len(glob.glob(os.path.join(processed_dataset_path, '*.h5'))):
    Dataset_Build = 'Load_Dataset'
else:
    Dataset_Build = 'New_Dataset'

if DatasetName == 'SIM10K_to_VOC12_resize_400_800':
    resize_image_to = (400, 800)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/VOCdevkit/VOC2012/JPEGImages'
    test_target_images_dir = '../../datasets/VOCdevkit/VOC2012/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/VOCdevkit/VOC2012/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    # The trainset of VOC which has 'car' object is used as train_target.
    train_target_image_set_filename = '../../datasets/VOCdevkit/VOC2012_CAR/ImageSets/Main/train_target.txt'
    # The valset of VOC which has 'car' object is used as test.
    test_target_image_set_filename = '../../datasets/VOCdevkit/VOC2012_CAR/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car',
                   'aeroplane', 'bicycle', 'bird', 'boat',
                   'bottle', 'bus', 'cat',
                   'chair', 'cow', 'diningtable', 'dog',
                   'horse', 'motorbike', 'person', 'pottedplant',
                   'sheep', 'sofa', 'train', 'tvmonitor']
    val_include_classes = [val_classes.index(one_class) for one_class in classes[1:]]
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'SIM10K_to_VOC07_resize_400_800':
    resize_image_to = (400, 800)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/VOCdevkit/VOC2007/JPEGImages'
    test_target_images_dir = '../../datasets/VOCdevkit/VOC2007/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/VOCdevkit/VOC2007/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    # The trainset of VOC which has 'car' object is used as train_target.
    train_target_image_set_filename = '../../datasets/VOCdevkit/VOC2007_CAR/ImageSets/Main/train_target.txt'
    # The valset of VOC which has 'car' object is used as test.
    test_target_image_set_filename = '../../datasets/VOCdevkit/VOC2007_CAR/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car',
                   'aeroplane', 'bicycle', 'bird', 'boat',
                   'bottle', 'bus', 'cat',
                   'chair', 'cow', 'diningtable', 'dog',
                   'horse', 'motorbike', 'person', 'pottedplant',
                   'sheep', 'sofa', 'train', 'tvmonitor']
    val_include_classes = [val_classes.index(one_class) for one_class in classes[1:]]
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'SIM10K_to_City_resize_400_800':
    resize_image_to = (400, 800)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/Cityscapes/JPEGImages'
    test_target_images_dir = '../../datasets/val_data_for_SIM10K_to_cityscapes/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/val_data_for_SIM10K_to_cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    test_target_image_set_filename = '../../datasets/val_data_for_SIM10K_to_cityscapes/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car']
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'City_to_foggy0_02_resize_400_800':
    resize_image_to = (400, 800)
    # Introduction of PascalVOC: https://arleyzhang.github.io/articles/1dc20586/
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/Cityscapes/JPEGImages'
    train_target_images_dir = '../../datasets/Cityscapes/JPEGImages'
    test_target_images_dir = '../../datasets/Cityscapes/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/Cityscapes/Annotations'
    test_annotation_dir = '../../datasets/Cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_target.txt'
    test_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/test.txt'
    # Our model will produce predictions for these classes.
    classes = ['background',
               'person', 'rider', 'car', 'truck',
               'bus', 'train', 'motorcycle', 'bicycle']
    train_classes = classes
    train_include_classes = 'all'
    val_classes = classes
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'City_to_foggy0_01_resize_400_800':
    resize_image_to = (400, 800)
    # Introduction of PascalVOC: https://arleyzhang.github.io/articles/1dc20586/
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/Cityscapes/JPEGImages'
    train_target_images_dir = '../../datasets/CITYSCAPES_beta_0_01/JPEGImages'
    test_target_images_dir = '../../datasets/CITYSCAPES_beta_0_01/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/Cityscapes/Annotations'
    test_annotation_dir = '../../datasets/Cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_target.txt'
    test_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/test.txt'
    # Our model will produce predictions for these classes.
    classes = ['background',
               'person', 'rider', 'car', 'truck',
               'bus', 'train', 'motorcycle', 'bicycle']
    train_classes = classes
    train_include_classes = 'all'
    val_classes = classes
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

else:
    raise ValueError('Undefined dataset name.')
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
if Model_Build == 'New_Model':
    # 1: Build the Keras model.

    K.clear_session()  # Clear previous models from memory.

    import tensorflow as tf
    from keras.backend.tensorflow_backend import set_session

    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
    config.log_device_placement = True  # to log device placement (on which device the operation ran)
    # (nothing gets printed in Jupyter, only if you run it standalone)
    sess = tf.Session(config=config)
    set_session(sess)  # set this TensorFlow session as the default session for Keras

    D_model, G_model = ssd_512(image_size=(img_height, img_width, img_channels),
                               n_classes=n_classes,
                               G_loss_weights=G_loss_weights,
                               D_loss_weights=D_loss_weights,
                               mode='training',
                               l2_regularization=0.0005,
                               scales=scales,
                               aspect_ratios_per_layer=aspect_ratios,
                               two_boxes_for_ar1=two_boxes_for_ar1,
                               steps=steps,
                               offsets=offsets,
                               clip_boxes=clip_boxes,
                               variances=variances,
                               normalize_coords=normalize_coords,
                               subtract_mean=mean_color,
                               swap_channels=swap_channels)

else:
    raise ValueError('Undefined Model_Build. Model_Build should be New_Model  or Load_Model')
# Out:
# D_network is Conv2

# %%
if Dataset_Build == 'New_Dataset':
    # 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

    # Optional: If you have enough memory, consider loading the images into memory for the reasons explained above.

    train_dataset = DataGenerator(dataset='train', load_images_into_memory=False, hdf5_dataset_path=None)
    val_dataset = DataGenerator(dataset='val', load_images_into_memory=False, hdf5_dataset_path=None)

    # 2: Parse the image and label lists for the training and validation datasets. This can take a while.
    # images_dirs, image_set_filenames, and annotations_dirs should have the same length
    train_dataset.parse_xml(images_dirs=[train_source_images_dir],
                            target_images_dirs=[train_target_images_dir],
                            image_set_filenames=[train_source_image_set_filename],
                            target_image_set_filenames=[train_target_image_set_filename],
                            annotations_dirs=[train_annotation_dir],
                            classes=train_classes,
                            include_classes=train_include_classes,
                            exclude_truncated=False,
                            exclude_difficult=False,
                            ret=False)

    val_dataset.parse_xml(images_dirs=[test_target_images_dir],
                          image_set_filenames=[test_target_image_set_filename],
                          annotations_dirs=[test_annotation_dir],
                          classes=val_classes,
                          include_classes=val_include_classes,
                          exclude_truncated=False,
                          exclude_difficult=True,
                          ret=False)

    # Optional: Convert the dataset into an HDF5 dataset. This will require more disk space, but will
    # speed up the training. Doing this is not relevant in case you activated the `load_images_into_memory`
    # option in the constructor, because in that cas the images are in memory already anyway. If you don't
    # want to create HDF5 datasets, comment out the subsequent two function calls.

    # After create these h5 files, if you have resized the input image, you need to reload these files. Otherwise,
    # the images and the labels will not change.

    train_dataset.create_hdf5_dataset(file_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                      resize=resize_image_to,
                                      variable_image_size=True,
                                      verbose=True)

    val_dataset.create_hdf5_dataset(file_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                    resize=False,
                                    variable_image_size=True,
                                    verbose=True)

    train_dataset = DataGenerator(dataset='train',
                                  load_images_into_memory=False,
                                  hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                  filenames=train_source_image_set_filename,
                                  target_filenames=train_target_image_set_filename,
                                  filenames_type='text',
                                  images_dir=train_source_images_dir,
                                  target_images_dir=train_target_images_dir)

    val_dataset = DataGenerator(dataset='val',
                                load_images_into_memory=False,
                                hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                filenames=test_target_image_set_filename,
                                filenames_type='text',
                                images_dir=test_target_images_dir)

elif Dataset_Build == 'Load_Dataset':
    # 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

    # Load dataset from the created h5 file.
    train_dataset = DataGenerator(dataset='train',
                                  load_images_into_memory=False,
                                  hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                  filenames=train_source_image_set_filename,
                                  target_filenames=train_target_image_set_filename,
                                  filenames_type='text',
                                  images_dir=train_source_images_dir,
                                  target_images_dir=train_target_images_dir)

    val_dataset = DataGenerator(dataset='val',
                                load_images_into_memory=False,
                                hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                filenames=test_target_image_set_filename,
                                filenames_type='text',
                                images_dir=test_target_images_dir)

else:
    raise ValueError('Undefined Dataset_Build. Dataset_Build should be New_Dataset or Load_Dataset.')
# Out:
# Loading source labels: 100%|██████████| 10000/10000 [00:02<00:00, 4832.14it/s]
# Loading source image IDs: 100%|██████████| 10000/10000 [00:00<00:00, 11016.88it/s]
# Loading target image IDs: 100%|██████████| 2966/2966 [00:00<00:00, 11140.63it/s]
# Loading evaluation-neutrality annotations: 100%|██████████| 10000/10000 [00:01<00:00, 8185.87it/s]
# Loading source labels: 100%|██████████| 479/479 [00:00<00:00, 5159.11it/s]
# Loading source image IDs: 100%|██████████| 479/479 [00:00<00:00, 11094.45it/s]
# Loading target image IDs: 0it [00:00, ?it/s]
# Loading evaluation-neutrality annotations: 100%|██████████| 479/479 [00:00<00:00, 6471.63it/s]

# %%
# 4: Set the image transformations for pre-processing and data augmentation options.

# For the training generator:
ssd_data_augmentation = SSDDataAugmentation_Siamese(img_height=img_height,
                                                    img_width=img_width)

# For the validation generator:
convert_to_3_channels = ConvertTo3Channels()
resize = Resize(height=img_height, width=img_width)

# 5: Instantiate an encoder that can encode ground truth labels into the format needed by the SSD loss function.

# The encoder constructor needs the spatial dimensions of the model's predictor layers to create the anchor boxes.
predictor_sizes = [G_model.get_layer('conv4_3_norm_mbox_conf').output_shape[1:3],
                   G_model.get_layer('fc7_mbox_conf').output_shape[1:3],
                   G_model.get_layer('conv6_2_mbox_conf').output_shape[1:3],
                   G_model.get_layer('conv7_2_mbox_conf').output_shape[1:3],
                   G_model.get_layer('conv8_2_mbox_conf').output_shape[1:3],
                   G_model.get_layer('conv9_2_mbox_conf').output_shape[1:3],
                   G_model.get_layer('conv10_2_mbox_conf').output_shape[1:3]]

ssd_input_encoder = SSDInputEncoder(img_height=img_height,
                                    img_width=img_width,
                                    n_classes=n_classes,
                                    predictor_sizes=predictor_sizes,
                                    scales=scales,
                                    aspect_ratios_per_layer=aspect_ratios,
                                    two_boxes_for_ar1=two_boxes_for_ar1,
                                    steps=steps,
                                    offsets=offsets,
                                    clip_boxes=clip_boxes,
                                    variances=variances,
                                    matching_type='multi',
                                    pos_iou_threshold=0.5,
                                    neg_iou_limit=0.5,
                                    normalize_coords=normalize_coords)

# 6: Create the generator handles that will be passed to Keras' `fit_generator()` function.
# The input image and label are first processed by transformations. Then, the label will be further encoded by
# ssd_input_encoder. The encoded labels are classId and offset to each anchor box.
# G_train_generator = train_dataset.generate(batch_size=batch_size,
#                                            generator_type='G',
#                                            shuffle=True,
#                                            transformations=[ssd_data_augmentation],
#                                            label_encoder=ssd_input_encoder,
#                                            returns={'processed_images',
#                                                     'encoded_labels'},
#                                            keep_images_without_gt=False)

# D_train_generator = train_dataset.generate(batch_size=batch_size,
#                                            generator_type='D',
#                                            shuffle=True,
#                                            transformations=[ssd_data_augmentation],
#                                            label_encoder=ssd_input_encoder,
#                                            returns={'processed_images',
#                                                     'encoded_labels'},
#                                            keep_images_without_gt=False)

# val_generator = val_dataset.generate(batch_size=batch_size,
#                                      generator_type='G',
#                                      shuffle=False,
#                                      transformations=[convert_to_3_channels,
#                                                       resize],
#                                      label_encoder=ssd_input_encoder,
#                                      returns={'processed_images',
#                                               'encoded_labels'},
#                                      keep_images_without_gt=False)

# Get the number of samples in the training and validations datasets.
train_dataset_size = train_dataset.get_dataset_size()
val_dataset_size = val_dataset.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size))
# Out:
# Number of images in the training dataset:	 10000
# Number of images in the validation dataset:	   479

# %%
num_epochss_real = 120
steps_per_G_epoch = 100
steps_per_D_epoch = 10
initial_epoch = 0
final_epoch = int(num_epochss_real * 370.0 / steps_per_G_epoch)
val_freq = int(final_epoch / num_epochss_real)

def lr_schedule(epoch):
    if epoch < 20:
        return 0.0005    
    elif epoch < int(0.7 * final_epoch):
        return 0.001
    elif epoch < int(0.9 * final_epoch):
        return 0.0001
    else:
        return 0.00001

# def lr_schedule(epoch):
#     if epoch < 20:
#         return 0.0005
#     elif epoch < 800:
#         return 0.001
#     elif epoch < 1000:
#         return 0.0001
#     else:
#         return 0.00001

# Define model callbacks.
# TODO: Set the filepath under which you want to save the model.
model_checkpoint = ModelCheckpoint(filepath=os.path.join(checkpoint_path, 'epoch-{epoch:02d}_loss-{loss:.4f}_val_loss-{val_loss:.4f}.h5'),
                                   monitor='val_loss',
                                   verbose=1,
                                   save_best_only=False,
                                   save_weights_only=True,
                                   mode='auto',
                                   period=1)

# model_checkpoint.best to the best validation loss from the previous training
# model_checkpoint.best = 4.83704

csv_logger = CSVLogger(filename=os.path.join(checkpoint_path, csv_file_name),
                       separator=',',
                       append=True)

learning_rate_scheduler = LearningRateScheduler(schedule=lr_schedule,
                                                verbose=1)

terminate_on_nan = TerminateOnNaN()

TensorBoard_monitor = TensorBoard(log_dir=checkpoint_path)

callbacks = [model_checkpoint,
             csv_logger,
             learning_rate_scheduler,
             terminate_on_nan,
             TensorBoard_monitor]

callbacks_no_val = [learning_rate_scheduler,
                    terminate_on_nan]

# def lr_schedule_D(epoch):
#     return 0.0005


# learning_rate_scheduler_D = LearningRateScheduler(schedule=lr_schedule_D,
#                                                   verbose=1)

# callbacks_no_val_D = [learning_rate_scheduler_D,
#                       terminate_on_nan]

# %%
for initial_epoch in range(final_epoch):
    try:
        print('\n')
        print('Train generator.')
        G_train_generator = train_dataset.generate(batch_size=batch_size,
                                                   generator_type='G',
                                                   shuffle=True,
                                                   transformations=[ssd_data_augmentation],
                                                   label_encoder=ssd_input_encoder,
                                                   returns={'processed_images',
                                                            'encoded_labels'},
                                                   keep_images_without_gt=False)  

        if initial_epoch != 0 and initial_epoch % val_freq == 0:
            val_generator = val_dataset.generate(batch_size=batch_size,
                                                 generator_type='G',
                                                 shuffle=False,
                                                 transformations=[convert_to_3_channels,
                                                                  resize],
                                                 label_encoder=ssd_input_encoder,
                                                 returns={'processed_images',
                                                          'encoded_labels'},
                                                 keep_images_without_gt=False)  

            history_G = G_model.fit_generator(generator=G_train_generator,
                                              steps_per_epoch=steps_per_G_epoch,
                                              epochs=initial_epoch+1,
                                              callbacks=callbacks,
                                              validation_data=val_generator,
                                              validation_steps=ceil(val_dataset_size/batch_size),
                                              initial_epoch=initial_epoch)

        else:
            history_G = G_model.fit_generator(generator=G_train_generator,
                                              steps_per_epoch=steps_per_G_epoch,
                                              epochs=initial_epoch+1,
                                              callbacks=callbacks_no_val,
                                              initial_epoch=initial_epoch)

        print('\n')
        print( 'Train discriminator.')
        D_train_generator = train_dataset.generate(batch_size=batch_size,
                                                   generator_type='D',
                                                   shuffle=True,
                                                   transformations=[ssd_data_augmentation],
                                                   label_encoder=ssd_input_encoder,
                                                   returns={'processed_images',
                                                            'encoded_labels'},
                                                   keep_images_without_gt=False)        

        history_D = D_model.fit_generator(generator=D_train_generator,
                                          steps_per_epoch=steps_per_D_epoch,
                                          epochs=initial_epoch+1,
                                          callbacks=callbacks_no_val,
                                          initial_epoch=initial_epoch)

    except ValueError:
        pass
# Out:
# Train generator.
# Epoch 1/1
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.0005.
# 100/100 [==============================] - 76s 759ms/step - loss: 19.5172 - D_model_loss: 9.0913 - predictions_loss: 15.9170
#
#
# Train discriminator.
# /usr/local/lib/python3.5/dist-packages/keras/engine/training.py:490: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# Epoch 1/1
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.0005.
# 10/10 [==============================] - 11s 1s/step - loss: 0.3588 - lambda_3_loss: 9.5610 - lambda_4_loss: 1.2394
#
#
# Train generator.
# Epoch 2/2
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0005.
# 100/100 [==============================] - 67s 669ms/step - loss: 20.0074 - D_model_loss: 2.6594 - predictions_loss: 16.3998
#
#
# Train discriminator.
# Epoch 2/2
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0005.
# 10/10 [==============================] - 4s 372ms/step - loss: 0.3585 - lambda_3_loss: 9.1297 - lambda_4_loss: 0.8098
#
#
# Train generator.
# Epoch 3/3
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.0005.
# 100/100 [==============================] - 65s 651ms/step - loss: 21.0139 - D_model_loss: 2.2877 - predictions_loss: 17.4095
#
#
# Train discriminator.
# Epoch 3/3
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.0005.
# 10/10 [==============================] - 4s 413ms/step - loss: 0.3583 - lambda_3_loss: 10.5933 - lambda_4_loss: 0.7940
#
#
# Train generator.
# Epoch 4/4
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.0005.
# 100/100 [==============================] - 103s 1s/step - loss: 21.2035 - D_model_loss: 1.8632 - predictions_loss: 17.6025 - val_loss: 19.0539 - val_D_model_loss: 0.0989 - val_predictions_loss: 15.4547
#
# Epoch 00004: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-04_loss-21.2035_val_loss-19.0539.h5
#
#
# Train discriminator.
# Epoch 4/4
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.0005.
# 10/10 [==============================] - 4s 362ms/step - loss: 0.3581 - lambda_3_loss: 11.2323 - lambda_4_loss: 0.7185
#
#
# Train generator.
# Epoch 5/5
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.0005.
# 100/100 [==============================] - 65s 651ms/step - loss: 20.8067 - D_model_loss: 1.9772 - predictions_loss: 17.2090
#
#
# Train discriminator.
# Epoch 5/5
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.0005.
# 10/10 [==============================] - 4s 360ms/step - loss: 0.3579 - lambda_3_loss: 11.3995 - lambda_4_loss: 1.2854
#
#
# Train generator.
# Epoch 6/6
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.0005.
# 100/100 [==============================] - 65s 651ms/step - loss: 22.2153 - D_model_loss: 1.5599 - predictions_loss: 18.6210
#
#
# Train discriminator.
# Epoch 6/6
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.0005.
# 10/10 [==============================] - 4s 365ms/step - loss: 0.3575 - lambda_3_loss: 9.8453 - lambda_4_loss: 1.1057
#
#
# Train generator.
# Epoch 7/7
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.0005.
# 100/100 [==============================] - 96s 957ms/step - loss: 21.4518 - D_model_loss: 2.3423 - predictions_loss: 17.8608 - val_loss: 20.6784 - val_D_model_loss: 0.2840 - val_predictions_loss: 17.0892
#
# Epoch 00007: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-07_loss-21.4608_val_loss-20.6784.h5
#
#
# Train discriminator.
# Epoch 7/7
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.0005.
# 10/10 [==============================] - 4s 411ms/step - loss: 0.3572 - lambda_3_loss: 9.8429 - lambda_4_loss: 0.7016
#
#
# Train generator.
# Epoch 8/8
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.0005.
# 100/100 [==============================] - 65s 650ms/step - loss: 21.1328 - D_model_loss: 2.6858 - predictions_loss: 17.5452
#
#
# Train discriminator.
# Epoch 8/8
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.0005.
# 10/10 [==============================] - 4s 351ms/step - loss: 0.3570 - lambda_3_loss: 11.1437 - lambda_4_loss: 0.8883
#
#
# Train generator.
# Epoch 9/9
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.0005.
#
#
# Train generator.
# Epoch 10/10
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.0005.
# 100/100 [==============================] - 115s 1s/step - loss: 20.0173 - D_model_loss: 2.7691 - predictions_loss: 16.4331 - val_loss: 17.9222 - val_D_model_loss: 0.9548 - val_predictions_loss: 14.3397
#
# Epoch 00010: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-10_loss-19.9848_val_loss-17.9222.h5
#
#
# Train discriminator.
# Epoch 10/10
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.0005.
# 10/10 [==============================] - 7s 701ms/step - loss: 0.3566 - lambda_3_loss: 9.1203 - lambda_4_loss: 1.8959
#
#
# Train generator.
# Epoch 11/11
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.0005.
# 100/100 [==============================] - 68s 677ms/step - loss: 20.3780 - D_model_loss: 2.2494 - predictions_loss: 16.7970
#
#
# Train discriminator.
# Epoch 11/11
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.0005.
# 10/10 [==============================] - 7s 683ms/step - loss: 0.3563 - lambda_3_loss: 10.3151 - lambda_4_loss: 0.8695
#
#
# Train generator.
# Epoch 12/12
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.0005.
# 100/100 [==============================] - 68s 677ms/step - loss: 19.4565 - D_model_loss: 3.5138 - predictions_loss: 15.8786
#
#
# Train discriminator.
# Epoch 12/12
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.0005.
# 10/10 [==============================] - 10s 964ms/step - loss: 0.3556 - lambda_3_loss: 5.8040 - lambda_4_loss: 1.0687
#
#
# Train generator.
# Epoch 13/13
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.0005.
# 100/100 [==============================] - 97s 975ms/step - loss: 19.3909 - D_model_loss: 5.2771 - predictions_loss: 15.8161 - val_loss: 17.4858 - val_D_model_loss: 8.1535 - val_predictions_loss: 13.9124
#
# Epoch 00013: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-13_loss-19.4015_val_loss-17.4858.h5
#
#
# Train discriminator.
# Epoch 13/13
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.0005.
# 10/10 [==============================] - 6s 596ms/step - loss: 0.3553 - lambda_3_loss: 5.2783 - lambda_4_loss: 1.0492
#
#
# Train generator.
# Epoch 14/14
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.0005.
# 100/100 [==============================] - 65s 649ms/step - loss: 18.5988 - D_model_loss: 5.9106 - predictions_loss: 15.0271
#
#
# Train discriminator.
# Epoch 14/14
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.0005.
# 10/10 [==============================] - 3s 349ms/step - loss: 0.3550 - lambda_3_loss: 4.5482 - lambda_4_loss: 1.7848
#
#
# Train generator.
# Epoch 15/15
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.0005.
# 100/100 [==============================] - 65s 655ms/step - loss: 16.5292 - D_model_loss: 7.0006 - predictions_loss: 12.9607
#
#
# Train discriminator.
# Epoch 15/15
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.0005.
# 10/10 [==============================] - 3s 342ms/step - loss: 0.3547 - lambda_3_loss: 4.9284 - lambda_4_loss: 0.9966
#
#
# Train generator.
# Epoch 16/16
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.0005.
# 100/100 [==============================] - 116s 1s/step - loss: 13.0779 - D_model_loss: 7.1236 - predictions_loss: 9.5123 - val_loss: 11.4660 - val_D_model_loss: 9.0818 - val_predictions_loss: 7.9017
#
# Epoch 00016: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-16_loss-13.0826_val_loss-11.4660.h5
#
#
# Train discriminator.
# Epoch 16/16
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.0005.
# 10/10 [==============================] - 5s 479ms/step - loss: 0.3545 - lambda_3_loss: 6.0774 - lambda_4_loss: 0.9991
#
#
# Train generator.
# Epoch 17/17
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.0005.
# 100/100 [==============================] - 67s 666ms/step - loss: 12.5120 - D_model_loss: 6.4071 - predictions_loss: 8.9497
#
#
# Train discriminator.
# Epoch 17/17
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.0005.
# 10/10 [==============================] - 6s 586ms/step - loss: 0.3541 - lambda_3_loss: 4.2698 - lambda_4_loss: 1.4698
#
#
# Train generator.
# Epoch 18/18
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.0005.
# 100/100 [==============================] - 67s 672ms/step - loss: 12.7132 - D_model_loss: 5.5177 - predictions_loss: 9.1541
#
#
# Train discriminator.
# Epoch 18/18
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.0005.
# 10/10 [==============================] - 6s 552ms/step - loss: 0.3539 - lambda_3_loss: 4.6436 - lambda_4_loss: 2.1067
#
#
# Train generator.
# Epoch 19/19
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.0005.
# 100/100 [==============================] - 120s 1s/step - loss: 12.7435 - D_model_loss: 6.3775 - predictions_loss: 9.1875 - val_loss: 10.5310 - val_D_model_loss: 6.0041 - val_predictions_loss: 6.9767
#
# Epoch 00019: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-19_loss-12.7435_val_loss-10.5310.h5
#
#
# Train discriminator.
# Epoch 19/19
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.0005.
# 10/10 [==============================] - 3s 348ms/step - loss: 0.3537 - lambda_3_loss: 5.7729 - lambda_4_loss: 1.0450
#
#
# Train generator.
# Epoch 20/20
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.0005.
# 100/100 [==============================] - 65s 651ms/step - loss: 12.6154 - D_model_loss: 5.5681 - predictions_loss: 9.0628
#
#
# Train discriminator.
# Epoch 20/20
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.0005.
# 10/10 [==============================] - 4s 359ms/step - loss: 0.3533 - lambda_3_loss: 5.1491 - lambda_4_loss: 1.1219
#
#
# Train generator.
# Epoch 21/21
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 65s 650ms/step - loss: 18.6397 - D_model_loss: 5.5452 - predictions_loss: 15.0887
#
#
# Train discriminator.
# Epoch 21/21
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 6s 578ms/step - loss: 0.3533 - lambda_3_loss: 6.6157 - lambda_4_loss: 3.0785
#
#
# Train generator.
# Epoch 22/22
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 109s 1s/step - loss: 26.5815 - D_model_loss: 5.9900 - predictions_loss: 23.0271 - val_loss: 25.2879 - val_D_model_loss: 6.0033 - val_predictions_loss: 21.7364
#
# Epoch 00022: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-22_loss-26.5988_val_loss-25.2879.h5
#
#
# Train discriminator.
# Epoch 22/22
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 378ms/step - loss: 0.3526 - lambda_3_loss: 5.0803 - lambda_4_loss: 3.3797
#
#
# Train generator.
# Epoch 23/23
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 65s 655ms/step - loss: 24.8335 - D_model_loss: 5.5418 - predictions_loss: 21.2852
#
#
# Train discriminator.
# Epoch 23/23
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 389ms/step - loss: 0.3520 - lambda_3_loss: 4.8718 - lambda_4_loss: 2.7567
#
#
# Train generator.
# Epoch 24/24
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 65s 651ms/step - loss: 25.3812 - D_model_loss: 3.7496 - predictions_loss: 21.8395
#
#
# Train discriminator.
# Epoch 24/24
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 3s 348ms/step - loss: 0.3516 - lambda_3_loss: 6.3412 - lambda_4_loss: 1.6861
#
#
# Train generator.
# Epoch 25/25
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 97s 974ms/step - loss: 23.9000 - D_model_loss: 3.3753 - predictions_loss: 20.3647 - val_loss: 24.1114 - val_D_model_loss: 2.0075 - val_predictions_loss: 20.5795
#
# Epoch 00025: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-25_loss-23.8963_val_loss-24.1114.h5
#
#
# Train discriminator.
# Epoch 25/25
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 3s 339ms/step - loss: 0.3510 - lambda_3_loss: 6.4854 - lambda_4_loss: 1.3821
#
#
# Train generator.
# Epoch 26/26
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 66s 661ms/step - loss: 25.9175 - D_model_loss: 3.7380 - predictions_loss: 22.3885
#
#
# Train discriminator.
# Epoch 26/26
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 380ms/step - loss: 0.3504 - lambda_3_loss: 5.8052 - lambda_4_loss: 0.8880
#
#
# Train generator.
# Epoch 27/27
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 66s 655ms/step - loss: 24.6172 - D_model_loss: 5.4308 - predictions_loss: 21.0944
#
#
# Train discriminator.
# Epoch 27/27
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 354ms/step - loss: 0.3496 - lambda_3_loss: 3.5365 - lambda_4_loss: 0.7808
#
#
# Train generator.
# Epoch 28/28
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 110s 1s/step - loss: 23.5997 - D_model_loss: 5.8066 - predictions_loss: 20.0832 - val_loss: 24.1058 - val_D_model_loss: 2.0837 - val_predictions_loss: 20.5930
#
# Epoch 00028: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-28_loss-23.5997_val_loss-24.1058.h5
#
#
# Train discriminator.
# Epoch 28/28
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 6s 624ms/step - loss: 0.3494 - lambda_3_loss: 6.0262 - lambda_4_loss: 1.0475
#
#
# Train generator.
# Epoch 29/29
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 67s 665ms/step - loss: 24.9004 - D_model_loss: 5.1862 - predictions_loss: 21.3904
#
#
# Train discriminator.
# Epoch 29/29
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 5s 543ms/step - loss: 0.3488 - lambda_3_loss: 5.2481 - lambda_4_loss: 0.9927
#
#
# Train generator.
# Epoch 30/30
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 67s 672ms/step - loss: 22.7035 - D_model_loss: 5.4922 - predictions_loss: 19.1997
#
#
# Train discriminator.
# Epoch 30/30
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 5s 548ms/step - loss: 0.3484 - lambda_3_loss: 5.9962 - lambda_4_loss: 0.8213
#
#
# Train generator.
# Epoch 31/31
#
# Epoch 00031: LearningRateScheduler setting learning rate to 0.001.
#
#
# Train generator.
# Epoch 32/32
#
# Epoch 00032: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 69s 688ms/step - loss: 25.3510 - D_model_loss: 6.6834 - predictions_loss: 21.8490
#
#
# Train discriminator.
# Epoch 32/32
#
# Epoch 00032: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 7s 662ms/step - loss: 0.3477 - lambda_3_loss: 1.8101 - lambda_4_loss: 3.5826
#
#
# Train generator.
# Epoch 33/33
#
# Epoch 00033: LearningRateScheduler setting learning rate to 0.001.
#
#
# Train generator.
# Epoch 34/34
#
# Epoch 00034: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 119s 1s/step - loss: 24.1549 - D_model_loss: 6.0268 - predictions_loss: 20.6589 - val_loss: 23.3007 - val_D_model_loss: 4.9615 - val_predictions_loss: 19.8080
#
# Epoch 00034: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-34_loss-24.1697_val_loss-23.3007.h5
#
#
# Train discriminator.
# Epoch 34/34
#
# Epoch 00034: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 8s 840ms/step - loss: 0.3472 - lambda_3_loss: 2.9828 - lambda_4_loss: 2.0269
#
#
# Train generator.
# Epoch 35/35
#
# Epoch 00035: LearningRateScheduler setting learning rate to 0.001.
#
#
# Train generator.
# Epoch 36/36
#
# Epoch 00036: LearningRateScheduler setting learning rate to 0.001.
#
#
# Train generator.
# Epoch 37/37
#
# Epoch 00037: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 117s 1s/step - loss: 13.6913 - D_model_loss: 4.8663 - predictions_loss: 10.2009 - val_loss: 12.5910 - val_D_model_loss: 1.4035 - val_predictions_loss: 9.1032
#
# Epoch 00037: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-37_loss-13.6913_val_loss-12.5910.h5
#
#
# Train discriminator.
# Epoch 37/37
#
# Epoch 00037: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 352ms/step - loss: 0.3471 - lambda_3_loss: 7.4803 - lambda_4_loss: 0.7585
#
#
# Train generator.
# Epoch 38/38
#
# Epoch 00038: LearningRateScheduler setting learning rate to 0.001.
#
#
# Train generator.
# Epoch 39/39
#
# Epoch 00039: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 69s 692ms/step - loss: 10.4173 - D_model_loss: 4.5309 - predictions_loss: 6.9312
#
#
# Train discriminator.
# Epoch 39/39
#
# Epoch 00039: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 352ms/step - loss: 0.3465 - lambda_3_loss: 5.8876 - lambda_4_loss: 0.2781
#
#
# Train generator.
# Epoch 40/40
#
# Epoch 00040: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 92s 920ms/step - loss: 9.4374 - D_model_loss: 5.2750 - predictions_loss: 5.9567 - val_loss: 9.0804 - val_D_model_loss: 2.1302 - val_predictions_loss: 5.6028
#
# Epoch 00040: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-40_loss-9.4354_val_loss-9.0804.h5
#
#
# Train discriminator.
# Epoch 40/40
#
# Epoch 00040: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 3s 339ms/step - loss: 0.3460 - lambda_3_loss: 5.2330 - lambda_4_loss: 0.4357
#
#
# Train generator.
# Epoch 41/41
#
# Epoch 00041: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 65s 651ms/step - loss: 8.9531 - D_model_loss: 5.7821 - predictions_loss: 5.4781
#
#
# Train discriminator.
# Epoch 41/41
#
# Epoch 00041: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 6s 575ms/step - loss: 0.3455 - lambda_3_loss: 4.3095 - lambda_4_loss: 1.1042
#
#
# Train generator.
# Epoch 42/42
#
# Epoch 00042: LearningRateScheduler setting learning rate to 0.001.
#
#
# Train generator.
# Epoch 43/43
#
# Epoch 00043: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 116s 1s/step - loss: 8.6272 - D_model_loss: 5.8144 - predictions_loss: 5.1582 - val_loss: 9.5506 - val_D_model_loss: 2.5037 - val_predictions_loss: 6.0851
#
# Epoch 00043: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-43_loss-8.6272_val_loss-9.5506.h5
#
#
# Train discriminator.
# Epoch 43/43
#
# Epoch 00043: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 387ms/step - loss: 0.3448 - lambda_3_loss: 2.7328 - lambda_4_loss: 1.2689
#
#
# Train generator.
# Epoch 44/44
#
# Epoch 00044: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 67s 670ms/step - loss: 8.6686 - D_model_loss: 5.3189 - predictions_loss: 5.2059
#
#
# Train discriminator.
# Epoch 44/44
#
# Epoch 00044: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 379ms/step - loss: 0.3444 - lambda_3_loss: 3.4406 - lambda_4_loss: 1.3625
#
#
# Train generator.
# Epoch 45/45
#
# Epoch 00045: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 67s 666ms/step - loss: 8.4388 - D_model_loss: 5.2578 - predictions_loss: 4.9821
#
#
# Train discriminator.
# Epoch 45/45
#
# Epoch 00045: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 6s 566ms/step - loss: 0.3439 - lambda_3_loss: 3.0342 - lambda_4_loss: 1.1881
#
#
# Train generator.
# Epoch 46/46
#
# Epoch 00046: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 95s 949ms/step - loss: 9.2597 - D_model_loss: 7.4310 - predictions_loss: 5.8081 - val_loss: 9.9141 - val_D_model_loss: 6.5993 - val_predictions_loss: 6.4653
#
# Epoch 00046: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-46_loss-9.2623_val_loss-9.9141.h5
#
#
# Train discriminator.
# Epoch 46/46
#
# Epoch 00046: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 368ms/step - loss: 0.3434 - lambda_3_loss: 2.8439 - lambda_4_loss: 1.5854
#
#
# Train generator.
# Epoch 47/47
#
# Epoch 00047: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 65s 653ms/step - loss: 8.9447 - D_model_loss: 7.0120 - predictions_loss: 5.4986
#
#
# Train discriminator.
# Epoch 47/47
#
# Epoch 00047: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 369ms/step - loss: 0.3430 - lambda_3_loss: 3.6503 - lambda_4_loss: 1.4781
#
#
# Train generator.
# Epoch 48/48
#
# Epoch 00048: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 65s 654ms/step - loss: 8.5400 - D_model_loss: 6.1353 - predictions_loss: 5.0999
#
#
# Train discriminator.
# Epoch 48/48
#
# Epoch 00048: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 377ms/step - loss: 0.3424 - lambda_3_loss: 2.8924 - lambda_4_loss: 0.9819
#
#
# Train generator.
# Epoch 49/49
#
# Epoch 00049: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 118s 1s/step - loss: 8.3980 - D_model_loss: 5.4317 - predictions_loss: 4.9640 - val_loss: 9.0676 - val_D_model_loss: 2.2444 - val_predictions_loss: 5.6369
#
# Epoch 00049: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-49_loss-8.3964_val_loss-9.0676.h5
#
#
# Train discriminator.
# Epoch 49/49
#
# Epoch 00049: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 377ms/step - loss: 0.3420 - lambda_3_loss: 3.9908 - lambda_4_loss: 0.7049
#
#
# Train generator.
# Epoch 50/50
#
# Epoch 00050: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 67s 666ms/step - loss: 8.3347 - D_model_loss: 5.8252 - predictions_loss: 4.9068
#
#
# Train discriminator.
# Epoch 50/50
#
# Epoch 00050: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 359ms/step - loss: 0.3416 - lambda_3_loss: 4.3841 - lambda_4_loss: 0.8631
#
#
# Train generator.
# Epoch 51/51
#
# Epoch 00051: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 68s 675ms/step - loss: 8.3145 - D_model_loss: 5.9701 - predictions_loss: 4.8924
#
#
# Train discriminator.
# Epoch 51/51
#
# Epoch 00051: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 5s 478ms/step - loss: 0.3411 - lambda_3_loss: 3.5116 - lambda_4_loss: 1.0841
#
#
# Train generator.
# Epoch 52/52
#
# Epoch 00052: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 105s 1s/step - loss: 8.2258 - D_model_loss: 6.3113 - predictions_loss: 4.8099 - val_loss: 9.1049 - val_D_model_loss: 2.5649 - val_predictions_loss: 5.6922
#
# Epoch 00052: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-52_loss-8.2262_val_loss-9.1049.h5
#
#
# Train discriminator.
# Epoch 52/52
#
# Epoch 00052: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 374ms/step - loss: 0.3406 - lambda_3_loss: 3.2278 - lambda_4_loss: 1.2202
#
#
# Train generator.
# Epoch 53/53
#
# Epoch 00053: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 67s 672ms/step - loss: 8.2570 - D_model_loss: 5.6357 - predictions_loss: 4.8470
#
#
# Train discriminator.
# Epoch 53/53
#
# Epoch 00053: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 5s 513ms/step - loss: 0.3401 - lambda_3_loss: 3.2122 - lambda_4_loss: 0.9303
#
#
# Train generator.
# Epoch 54/54
#
# Epoch 00054: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 67s 673ms/step - loss: 8.3390 - D_model_loss: 5.7913 - predictions_loss: 4.9348
#
#
# Train discriminator.
# Epoch 54/54
#
# Epoch 00054: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 402ms/step - loss: 0.3398 - lambda_3_loss: 3.7844 - lambda_4_loss: 1.8378
#
#
# Train generator.
# Epoch 55/55
#
# Epoch 00055: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 117s 1s/step - loss: 7.8759 - D_model_loss: 6.8235 - predictions_loss: 4.4775 - val_loss: 9.1310 - val_D_model_loss: 3.8738 - val_predictions_loss: 5.7360
#
# Epoch 00055: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-55_loss-7.8759_val_loss-9.1310.h5
#
#
# Train discriminator.
# Epoch 55/55
#
# Epoch 00055: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 6s 561ms/step - loss: 0.3392 - lambda_3_loss: 3.2826 - lambda_4_loss: 1.4870
#
#
# Train generator.
# Epoch 56/56
#
# Epoch 00056: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 66s 664ms/step - loss: 8.0883 - D_model_loss: 6.5405 - predictions_loss: 4.6960
#
#
# Train discriminator.
# Epoch 56/56
#
# Epoch 00056: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 3s 343ms/step - loss: 0.3387 - lambda_3_loss: 3.2921 - lambda_4_loss: 1.1712
#
#
# Train generator.
# Epoch 57/57
#
# Epoch 00057: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 67s 669ms/step - loss: 7.8229 - D_model_loss: 7.7880 - predictions_loss: 4.4365
#
#
# Train discriminator.
# Epoch 57/57
#
# Epoch 00057: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 362ms/step - loss: 0.3383 - lambda_3_loss: 4.1577 - lambda_4_loss: 1.1347
#
#
# Train generator.
# Epoch 58/58
#
# Epoch 00058: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 103s 1s/step - loss: 7.7309 - D_model_loss: 7.9893 - predictions_loss: 4.3507 - val_loss: 9.2610 - val_D_model_loss: 3.0189 - val_predictions_loss: 5.8844
#
# Epoch 00058: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-58_loss-7.7306_val_loss-9.2610.h5
#
#
# Train discriminator.
# Epoch 58/58
#
# Epoch 00058: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 379ms/step - loss: 0.3375 - lambda_3_loss: 1.2086 - lambda_4_loss: 0.9255
#
#
# Train generator.
# Epoch 59/59
#
# Epoch 00059: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 65s 649ms/step - loss: 7.9284 - D_model_loss: 8.5204 - predictions_loss: 4.5543
#
#
# Train discriminator.
# Epoch 59/59
#
# Epoch 00059: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 367ms/step - loss: 0.3372 - lambda_3_loss: 2.8145 - lambda_4_loss: 0.9257
#
#
# Train generator.
# Epoch 60/60
#
# Epoch 00060: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 65s 654ms/step - loss: 7.9966 - D_model_loss: 7.0507 - predictions_loss: 4.6285
#
#
# Train discriminator.
# Epoch 60/60
#
# Epoch 00060: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 363ms/step - loss: 0.3369 - lambda_3_loss: 5.3285 - lambda_4_loss: 0.3442
#
#
# Train generator.
# Epoch 61/61
#
# Epoch 00061: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 97s 973ms/step - loss: 7.7411 - D_model_loss: 6.0498 - predictions_loss: 4.3792 - val_loss: 8.6868 - val_D_model_loss: 0.6749 - val_predictions_loss: 5.3285
#
# Epoch 00061: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-61_loss-7.7408_val_loss-8.6868.h5
#
#
# Train discriminator.
# Epoch 61/61
#
# Epoch 00061: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 3s 350ms/step - loss: 0.3363 - lambda_3_loss: 4.2775 - lambda_4_loss: 0.3502
#
#
# Train generator.
# Epoch 62/62
#
# Epoch 00062: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 65s 651ms/step - loss: 7.8416 - D_model_loss: 6.5873 - predictions_loss: 4.4857
#
#
# Train discriminator.
# Epoch 62/62
#
# Epoch 00062: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 372ms/step - loss: 0.3359 - lambda_3_loss: 4.1924 - lambda_4_loss: 0.9651
#
#
# Train generator.
# Epoch 63/63
#
# Epoch 00063: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 65s 654ms/step - loss: 7.9499 - D_model_loss: 7.2785 - predictions_loss: 4.5999
#
#
# Train discriminator.
# Epoch 63/63
#
# Epoch 00063: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 3s 310ms/step - loss: 0.3355 - lambda_3_loss: 4.1566 - lambda_4_loss: 1.1462
#
#
# Train generator.
# Epoch 64/64
#
# Epoch 00064: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 92s 923ms/step - loss: 7.7849 - D_model_loss: 8.0278 - predictions_loss: 4.4406 - val_loss: 9.4086 - val_D_model_loss: 1.6045 - val_predictions_loss: 6.0679
#
# Epoch 00064: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-64_loss-7.7839_val_loss-9.4086.h5
#
#
# Train discriminator.
# Epoch 64/64
#
# Epoch 00064: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 398ms/step - loss: 0.3348 - lambda_3_loss: 3.0648 - lambda_4_loss: 0.5034
#
#
# Train generator.
# Epoch 65/65
#
# Epoch 00065: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 65s 652ms/step - loss: 7.6333 - D_model_loss: 8.0614 - predictions_loss: 4.2950
#
#
# Train discriminator.
# Epoch 65/65
#
# Epoch 00065: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 358ms/step - loss: 0.3343 - lambda_3_loss: 2.1838 - lambda_4_loss: 1.1063
#
#
# Train generator.
# Epoch 66/66
#
# Epoch 00066: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 66s 656ms/step - loss: 7.6591 - D_model_loss: 8.8703 - predictions_loss: 4.3267
#
#
# Train discriminator.
# Epoch 66/66
#
# Epoch 00066: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 5s 471ms/step - loss: 0.3338 - lambda_3_loss: 1.3632 - lambda_4_loss: 1.7284
#
#
# Train generator.
# Epoch 67/67
#
# Epoch 00067: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 99s 992ms/step - loss: 7.6221 - D_model_loss: 8.5474 - predictions_loss: 4.2958 - val_loss: 8.8456 - val_D_model_loss: 3.2402 - val_predictions_loss: 5.5227
#
# Epoch 00067: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-67_loss-7.6242_val_loss-8.8456.h5
#
#
# Train discriminator.
# Epoch 67/67
#
# Epoch 00067: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 375ms/step - loss: 0.3333 - lambda_3_loss: 1.7733 - lambda_4_loss: 0.7133
#
#
# Train generator.
# Epoch 68/68
#
# Epoch 00068: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 65s 653ms/step - loss: 7.6734 - D_model_loss: 7.4187 - predictions_loss: 4.3530
#
#
# Train discriminator.
# Epoch 68/68
#
# Epoch 00068: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 3s 348ms/step - loss: 0.3329 - lambda_3_loss: 2.2731 - lambda_4_loss: 0.9730
#
#
# Train generator.
# Epoch 69/69
#
# Epoch 00069: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 65s 655ms/step - loss: 7.5903 - D_model_loss: 7.3516 - predictions_loss: 4.2758
#
#
# Train discriminator.
# Epoch 69/69
#
# Epoch 00069: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 351ms/step - loss: 0.3324 - lambda_3_loss: 2.4325 - lambda_4_loss: 0.2010
#
#
# Train generator.
# Epoch 70/70
#
# Epoch 00070: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 101s 1s/step - loss: 7.5146 - D_model_loss: 7.8734 - predictions_loss: 4.2060 - val_loss: 8.6993 - val_D_model_loss: 1.2813 - val_predictions_loss: 5.3944
#
# Epoch 00070: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-70_loss-7.5146_val_loss-8.6993.h5
#
#
# Train discriminator.
# Epoch 70/70
#
# Epoch 00070: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 3s 338ms/step - loss: 0.3321 - lambda_3_loss: 3.6519 - lambda_4_loss: 0.7096
#
#
# Train generator.
# Epoch 71/71
#
# Epoch 00071: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 66s 660ms/step - loss: 7.9668 - D_model_loss: 8.0223 - predictions_loss: 4.6641
#
#
# Train discriminator.
# Epoch 71/71
#
# Epoch 00071: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 5s 542ms/step - loss: 0.3315 - lambda_3_loss: 2.1458 - lambda_4_loss: 0.9013
#
#
# Train generator.
# Epoch 72/72
#
# Epoch 00072: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 65s 650ms/step - loss: 7.6306 - D_model_loss: 9.0311 - predictions_loss: 4.3334
#
#
# Train discriminator.
# Epoch 72/72
#
# Epoch 00072: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 11s 1s/step - loss: 0.3312 - lambda_3_loss: 2.8700 - lambda_4_loss: 1.8552
#
#
# Train generator.
# Epoch 73/73
#
# Epoch 00073: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 92s 922ms/step - loss: 7.8093 - D_model_loss: 9.3077 - predictions_loss: 4.5172 - val_loss: 8.6592 - val_D_model_loss: 10.4123 - val_predictions_loss: 5.3689
#
# Epoch 00073: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-73_loss-7.8109_val_loss-8.6592.h5
#
#
# Train discriminator.
# Epoch 73/73
#
# Epoch 00073: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 3s 317ms/step - loss: 0.3311 - lambda_3_loss: 0.3677 - lambda_4_loss: 6.7449
#
#
# Train generator.
# Epoch 74/74
#
# Epoch 00074: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 65s 652ms/step - loss: 7.4830 - D_model_loss: 9.1250 - predictions_loss: 4.1956
#
#
# Train discriminator.
# Epoch 74/74
#
# Epoch 00074: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 380ms/step - loss: 0.3302 - lambda_3_loss: 1.7511 - lambda_4_loss: 0.9429
#
#
# Train generator.
# Epoch 75/75
#
# Epoch 00075: LearningRateScheduler setting learning rate to 0.001.
#
#
# Train generator.
# Epoch 76/76
#
# Epoch 00076: LearningRateScheduler setting learning rate to 0.001.
#
#
# Train generator.
# Epoch 77/77
#
# Epoch 00077: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 66s 655ms/step - loss: 7.6080 - D_model_loss: 8.1057 - predictions_loss: 4.3265
#
#
# Train discriminator.
# Epoch 77/77
#
# Epoch 00077: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 8s 767ms/step - loss: 0.3299 - lambda_3_loss: 3.4499 - lambda_4_loss: 0.3295
#
#
# Train generator.
# Epoch 78/78
#
# Epoch 00078: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 68s 675ms/step - loss: 7.6073 - D_model_loss: 10.0471 - predictions_loss: 4.3313
#
#
# Train discriminator.
# Epoch 78/78
#
# Epoch 00078: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 8s 755ms/step - loss: 0.3293 - lambda_3_loss: 1.1629 - lambda_4_loss: 1.4474
#
#
# Train generator.
# Epoch 79/79
#
# Epoch 00079: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 101s 1s/step - loss: 7.4420 - D_model_loss: 11.7481 - predictions_loss: 4.1717 - val_loss: 8.5317 - val_D_model_loss: 4.9478 - val_predictions_loss: 5.2651
#
# Epoch 00079: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-79_loss-7.4411_val_loss-8.5317.h5
#
#
# Train discriminator.
# Epoch 79/79
#
# Epoch 00079: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 6s 562ms/step - loss: 0.3288 - lambda_3_loss: 0.7457 - lambda_4_loss: 1.3799
#
#
# Train generator.
# Epoch 80/80
#
# Epoch 00080: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 65s 648ms/step - loss: 7.4631 - D_model_loss: 10.5139 - predictions_loss: 4.1988
#
#
# Train discriminator.
# Epoch 80/80
#
# Epoch 00080: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 6s 600ms/step - loss: 0.3283 - lambda_3_loss: 0.5793 - lambda_4_loss: 1.8054
#
#
# Train generator.
# Epoch 81/81
#
# Epoch 00081: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 65s 653ms/step - loss: 7.6026 - D_model_loss: 9.7047 - predictions_loss: 4.3442
#
#
# Train discriminator.
# Epoch 81/81
#
# Epoch 00081: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 6s 553ms/step - loss: 0.3278 - lambda_3_loss: 0.6511 - lambda_4_loss: 0.8854
#
#
# Train generator.
# Epoch 82/82
#
# Epoch 00082: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 97s 969ms/step - loss: 7.5625 - D_model_loss: 9.6736 - predictions_loss: 4.3099 - val_loss: 8.6171 - val_D_model_loss: 2.5948 - val_predictions_loss: 5.3681
#
# Epoch 00082: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-82_loss-7.5636_val_loss-8.6171.h5
#
#
# Train discriminator.
# Epoch 82/82
#
# Epoch 00082: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 6s 562ms/step - loss: 0.3274 - lambda_3_loss: 1.2848 - lambda_4_loss: 0.5779
#
#
# Train generator.
# Epoch 83/83
#
# Epoch 00083: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 66s 660ms/step - loss: 7.3953 - D_model_loss: 9.0704 - predictions_loss: 4.1485
#
#
# Train discriminator.
# Epoch 83/83
#
# Epoch 00083: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 6s 560ms/step - loss: 0.3268 - lambda_3_loss: 0.7567 - lambda_4_loss: 0.3967
#
#
# Train generator.
# Epoch 84/84
#
# Epoch 00084: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 70s 696ms/step - loss: 7.4412 - D_model_loss: 10.2450 - predictions_loss: 4.2000
#
#
# Train discriminator.
# Epoch 84/84
#
# Epoch 00084: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 382ms/step - loss: 0.3264 - lambda_3_loss: 0.5658 - lambda_4_loss: 0.5687
#
#
# Train generator.
# Epoch 85/85
#
# Epoch 00085: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 100s 998ms/step - loss: 7.4853 - D_model_loss: 9.9508 - predictions_loss: 4.2499 - val_loss: 8.6808 - val_D_model_loss: 1.5456 - val_predictions_loss: 5.4490
#
# Epoch 00085: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-85_loss-7.4867_val_loss-8.6808.h5
#
#
# Train discriminator.
# Epoch 85/85
#
# Epoch 00085: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 379ms/step - loss: 0.3259 - lambda_3_loss: 0.5693 - lambda_4_loss: 0.2532
#
#
# Train generator.
# Epoch 86/86
#
# Epoch 00086: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 67s 673ms/step - loss: 7.3585 - D_model_loss: 10.2174 - predictions_loss: 4.1287
#
#
# Train discriminator.
# Epoch 86/86
#
# Epoch 00086: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 375ms/step - loss: 0.3256 - lambda_3_loss: 2.6927 - lambda_4_loss: 0.1604
#
#
# Train generator.
# Epoch 87/87
#
# Epoch 00087: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 68s 677ms/step - loss: 7.3658 - D_model_loss: 8.5468 - predictions_loss: 4.1420
#
#
# Train discriminator.
# Epoch 87/87
#
# Epoch 00087: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 358ms/step - loss: 0.3251 - lambda_3_loss: 1.8044 - lambda_4_loss: 0.1785
#
#
# Train generator.
# Epoch 88/88
#
# Epoch 00088: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 98s 981ms/step - loss: 7.3583 - D_model_loss: 9.7126 - predictions_loss: 4.1402 - val_loss: 8.4187 - val_D_model_loss: 1.1164 - val_predictions_loss: 5.2043
#
# Epoch 00088: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-88_loss-7.3579_val_loss-8.4187.h5
#
#
# Train discriminator.
# Epoch 88/88
#
# Epoch 00088: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 5s 510ms/step - loss: 0.3247 - lambda_3_loss: 1.9844 - lambda_4_loss: 0.7100
#
#
# Train generator.
# Epoch 89/89
#
# Epoch 00089: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 65s 648ms/step - loss: 7.2093 - D_model_loss: 9.3565 - predictions_loss: 3.9970
#
#
# Train discriminator.
# Epoch 89/89
#
# Epoch 00089: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 6s 566ms/step - loss: 0.3242 - lambda_3_loss: 1.4406 - lambda_4_loss: 0.6534
#
#
# Train generator.
# Epoch 90/90
#
# Epoch 00090: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 65s 647ms/step - loss: 7.2250 - D_model_loss: 10.3259 - predictions_loss: 4.0184
#
#
# Train discriminator.
# Epoch 90/90
#
# Epoch 00090: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 397ms/step - loss: 0.3237 - lambda_3_loss: 0.8679 - lambda_4_loss: 1.1155
#
#
# Train generator.
# Epoch 91/91
#
# Epoch 00091: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 236s 2s/step - loss: 7.3077 - D_model_loss: 9.0958 - predictions_loss: 4.1070 - val_loss: 8.5130 - val_D_model_loss: 0.8571 - val_predictions_loss: 5.3160
#
# Epoch 00091: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-91_loss-7.3088_val_loss-8.5130.h5
#
#
# Train discriminator.
# Epoch 91/91
#
# Epoch 00091: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 5s 479ms/step - loss: 0.3233 - lambda_3_loss: 2.0006 - lambda_4_loss: 0.3925
#
#
# Train generator.
# Epoch 92/92
#
# Epoch 00092: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 75s 753ms/step - loss: 7.2998 - D_model_loss: 9.6590 - predictions_loss: 4.1049
#
#
# Train discriminator.
# Epoch 92/92
#
# Epoch 00092: LearningRateScheduler setting learning rate to 0.001.
#
#
# Train generator.
# Epoch 93/93
#
# Epoch 00093: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 68s 680ms/step - loss: 7.2759 - D_model_loss: 9.5372 - predictions_loss: 4.0865
#
#
# Train discriminator.
# Epoch 93/93
#
# Epoch 00093: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 8s 757ms/step - loss: 0.3224 - lambda_3_loss: 0.5339 - lambda_4_loss: 1.0364
#
#
# Train generator.
# Epoch 94/94
#
# Epoch 00094: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 99s 992ms/step - loss: 7.3446 - D_model_loss: 8.9294 - predictions_loss: 4.1608 - val_loss: 8.2924 - val_D_model_loss: 0.8937 - val_predictions_loss: 5.1123
#
# Epoch 00094: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-94_loss-7.3444_val_loss-8.2924.h5
#
#
# Train discriminator.
# Epoch 94/94
#
# Epoch 00094: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 8s 829ms/step - loss: 0.3219 - lambda_3_loss: 1.1177 - lambda_4_loss: 0.7103
#
#
# Train generator.
# Epoch 95/95
#
# Epoch 00095: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 65s 647ms/step - loss: 7.3625 - D_model_loss: 8.9007 - predictions_loss: 4.1844
#
#
# Train discriminator.
# Epoch 95/95
#
# Epoch 00095: LearningRateScheduler setting learning rate to 0.001.
#
#
# Train generator.
# Epoch 96/96
#
# Epoch 00096: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 66s 657ms/step - loss: 7.4017 - D_model_loss: 9.4737 - predictions_loss: 4.2291
#
#
# Train discriminator.
# Epoch 96/96
#
# Epoch 00096: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 3s 344ms/step - loss: 0.3210 - lambda_3_loss: 1.1532 - lambda_4_loss: 0.2852
#
#
# Train generator.
# Epoch 97/97
#
# Epoch 00097: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 224s 2s/step - loss: 7.3420 - D_model_loss: 7.8788 - predictions_loss: 4.1750 - val_loss: 8.4320 - val_D_model_loss: 0.2376 - val_predictions_loss: 5.2685
#
# Epoch 00097: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-97_loss-7.3399_val_loss-8.4320.h5
#
#
# Train discriminator.
# Epoch 97/97
#
# Epoch 00097: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 7s 665ms/step - loss: 0.3209 - lambda_3_loss: 3.8789 - lambda_4_loss: 0.1059
#
#
# Train generator.
# Epoch 98/98
#
# Epoch 00098: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 67s 670ms/step - loss: 7.2552 - D_model_loss: 8.2171 - predictions_loss: 4.0937
#
#
# Train discriminator.
# Epoch 98/98
#
# Epoch 00098: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 5s 511ms/step - loss: 0.3202 - lambda_3_loss: 1.6020 - lambda_4_loss: 0.4190
#
#
# Train generator.
# Epoch 99/99
#
# Epoch 00099: LearningRateScheduler setting learning rate to 0.001.
#
#
# Train generator.
# Epoch 100/100
#
# Epoch 00100: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 155s 2s/step - loss: 7.1954 - D_model_loss: 9.0472 - predictions_loss: 4.0395 - val_loss: 8.1532 - val_D_model_loss: 0.5903 - val_predictions_loss: 5.0009
#
# Epoch 00100: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-100_loss-7.1977_val_loss-8.1532.h5
#
#
# Train discriminator.
# Epoch 100/100
#
# Epoch 00100: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 412ms/step - loss: 0.3198 - lambda_3_loss: 1.5274 - lambda_4_loss: 0.4195
#
#
# Train generator.
# Epoch 101/101
#
# Epoch 00101: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 68s 677ms/step - loss: 7.1897 - D_model_loss: 9.3731 - predictions_loss: 4.0394
#
#
# Train discriminator.
# Epoch 101/101
#
# Epoch 00101: LearningRateScheduler setting learning rate to 0.001.
# ...
#
# Epoch 00301: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-301_loss-6.0205_val_loss-7.2879.h5
#
#
# Train discriminator.
# Epoch 301/301
#
# Epoch 00301: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 3s 331ms/step - loss: 0.2512 - lambda_3_loss: 0.1629 - lambda_4_loss: 0.0698
#
#
# Train generator.
# Epoch 302/302
#
# Epoch 00302: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 65s 655ms/step - loss: 5.8418 - D_model_loss: 11.0237 - predictions_loss: 3.5451
#
#
# Train discriminator.
# Epoch 302/302
#
# Epoch 00302: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 3s 332ms/step - loss: 0.2509 - lambda_3_loss: 0.0262 - lambda_4_loss: 0.0555
#
#
# Train generator.
# Epoch 303/303
#
# Epoch 00303: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 66s 664ms/step - loss: 5.9411 - D_model_loss: 9.5609 - predictions_loss: 3.6483
#
#
# Train discriminator.
# Epoch 303/303
#
# Epoch 00303: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 369ms/step - loss: 0.2506 - lambda_3_loss: 0.0793 - lambda_4_loss: 0.0603
#
#
# Train generator.
# Epoch 304/304
#
# Epoch 00304: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 93s 929ms/step - loss: 5.8220 - D_model_loss: 10.3128 - predictions_loss: 3.5330 - val_loss: 7.1690 - val_D_model_loss: 0.0923 - val_predictions_loss: 4.8830
#
# Epoch 00304: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-304_loss-5.8235_val_loss-7.1690.h5
#
#
# Train discriminator.
# Epoch 304/304
#
# Epoch 00304: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 371ms/step - loss: 0.2503 - lambda_3_loss: 0.7033 - lambda_4_loss: 0.0287
#
#
# Train generator.
# Epoch 305/305
#
# Epoch 00305: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 65s 655ms/step - loss: 5.8373 - D_model_loss: 8.7507 - predictions_loss: 3.5523
#
#
# Train discriminator.
# Epoch 305/305
#
# Epoch 00305: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 3s 345ms/step - loss: 0.2500 - lambda_3_loss: 0.3535 - lambda_4_loss: 0.0493
#
#
# Train generator.
# Epoch 306/306
#
# Epoch 00306: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 66s 664ms/step - loss: 5.8954 - D_model_loss: 10.0962 - predictions_loss: 3.6141
#
#
# Train discriminator.
# Epoch 306/306
#
# Epoch 00306: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 385ms/step - loss: 0.2496 - lambda_3_loss: 0.0957 - lambda_4_loss: 0.1222
#
#
# Train generator.
# Epoch 307/307
#
# Epoch 00307: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 112s 1s/step - loss: 5.9428 - D_model_loss: 11.5193 - predictions_loss: 3.6653 - val_loss: 7.2399 - val_D_model_loss: 0.4787 - val_predictions_loss: 4.9653
#
# Epoch 00307: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-307_loss-5.9446_val_loss-7.2399.h5
#
#
# Train discriminator.
# Epoch 307/307
#
# Epoch 00307: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 357ms/step - loss: 0.2493 - lambda_3_loss: 0.1133 - lambda_4_loss: 0.0958
#
#
# Train generator.
# Epoch 308/308
#
# Epoch 00308: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 65s 655ms/step - loss: 5.8265 - D_model_loss: 10.8789 - predictions_loss: 3.5528
#
#
# Train discriminator.
# Epoch 308/308
#
# Epoch 00308: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 353ms/step - loss: 0.2491 - lambda_3_loss: 1.1048 - lambda_4_loss: 0.0579
#
#
# Train generator.
# Epoch 309/309
#
# Epoch 00309: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 66s 662ms/step - loss: 5.9466 - D_model_loss: 9.5615 - predictions_loss: 3.6767
#
#
# Train discriminator.
# Epoch 309/309
#
# Epoch 00309: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 3s 321ms/step - loss: 0.2487 - lambda_3_loss: 0.1718 - lambda_4_loss: 0.1071
#
#
# Train generator.
# Epoch 310/310
#
# Epoch 00310: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - 105s 1s/step - loss: 5.7605 - D_model_loss: 9.3908 - predictions_loss: 3.4944 - val_loss: 7.0183 - val_D_model_loss: 0.1684 - val_predictions_loss: 4.7551
#
# Epoch 00310: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-310_loss-5.7610_val_loss-7.0183.h5
#
#
# Train discriminator.
# Epoch 310/310
#
# Epoch 00310: LearningRateScheduler setting learning rate to 0.001.
# 10/10 [==============================] - 4s 407ms/step - loss: 0.2484 - lambda_3_loss: 0.2043 - lambda_4_loss: 0.1991
#
#
# Train generator.
# Epoch 311/311
#
# Epoch 00311: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 67s 674ms/step - loss: 5.7954 - D_model_loss: 8.1943 - predictions_loss: 3.5318
#
#
# Train discriminator.
# Epoch 311/311
#
# Epoch 00311: LearningRateScheduler setting learning rate to 0.0001.
#
#
# Train generator.
# Epoch 312/312
#
# Epoch 00312: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 68s 678ms/step - loss: 5.6174 - D_model_loss: 9.2625 - predictions_loss: 3.3542
#
#
# Train discriminator.
# Epoch 312/312
#
# Epoch 00312: LearningRateScheduler setting learning rate to 0.0001.
#
#
# Train generator.
# Epoch 313/313
#
# Epoch 00313: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 114s 1s/step - loss: 5.6212 - D_model_loss: 9.2596 - predictions_loss: 3.3584 - val_loss: 6.9918 - val_D_model_loss: 0.1362 - val_predictions_loss: 4.7301
#
# Epoch 00313: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-313_loss-5.6232_val_loss-6.9918.h5
#
#
# Train discriminator.
# Epoch 313/313
#
# Epoch 00313: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 3s 347ms/step - loss: 0.2483 - lambda_3_loss: 0.1877 - lambda_4_loss: 0.1720
#
#
# Train generator.
# Epoch 314/314
#
# Epoch 00314: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 66s 657ms/step - loss: 5.6441 - D_model_loss: 9.7821 - predictions_loss: 3.3817
#
#
# Train discriminator.
# Epoch 314/314
#
# Epoch 00314: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 3s 343ms/step - loss: 0.2483 - lambda_3_loss: 0.2500 - lambda_4_loss: 0.0808
#
#
# Train generator.
# Epoch 315/315
#
# Epoch 00315: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 66s 661ms/step - loss: 5.6361 - D_model_loss: 9.4231 - predictions_loss: 3.3742
#
#
# Train discriminator.
# Epoch 315/315
#
# Epoch 00315: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 4s 366ms/step - loss: 0.2482 - lambda_3_loss: 0.1966 - lambda_4_loss: 0.0487
#
#
# Train generator.
# Epoch 316/316
#
# Epoch 00316: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 93s 927ms/step - loss: 5.6659 - D_model_loss: 9.8538 - predictions_loss: 3.4044 - val_loss: 6.9468 - val_D_model_loss: 0.1755 - val_predictions_loss: 4.6865
#
# Epoch 00316: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-316_loss-5.6639_val_loss-6.9468.h5
#
#
# Train discriminator.
# Epoch 316/316
#
# Epoch 00316: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 4s 395ms/step - loss: 0.2482 - lambda_3_loss: 0.4492 - lambda_4_loss: 0.0645
#
#
# Train generator.
# Epoch 317/317
#
# Epoch 00317: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 67s 666ms/step - loss: 5.6908 - D_model_loss: 10.4455 - predictions_loss: 3.4296
#
#
# Train discriminator.
# Epoch 317/317
#
# Epoch 00317: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 4s 386ms/step - loss: 0.2481 - lambda_3_loss: 0.1481 - lambda_4_loss: 0.0368
#
#
# Train generator.
# Epoch 318/318
#
# Epoch 00318: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 67s 667ms/step - loss: 5.6161 - D_model_loss: 10.1772 - predictions_loss: 3.3554
#
#
# Train discriminator.
# Epoch 318/318
#
# Epoch 00318: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 3s 331ms/step - loss: 0.2481 - lambda_3_loss: 0.1932 - lambda_4_loss: 0.2920
#
#
# Train generator.
# Epoch 319/319
#
# Epoch 00319: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 98s 984ms/step - loss: 5.5995 - D_model_loss: 10.2889 - predictions_loss: 3.3393 - val_loss: 6.9586 - val_D_model_loss: 0.1445 - val_predictions_loss: 4.6996
#
# Epoch 00319: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-319_loss-5.6015_val_loss-6.9586.h5
#
#
# Train discriminator.
# Epoch 319/319
#
# Epoch 00319: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 4s 365ms/step - loss: 0.2481 - lambda_3_loss: 0.2354 - lambda_4_loss: 0.0233
#
#
# Train generator.
# Epoch 320/320
#
# Epoch 00320: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 66s 656ms/step - loss: 5.4895 - D_model_loss: 9.8247 - predictions_loss: 3.2297
#
#
# Train discriminator.
# Epoch 320/320
#
# Epoch 00320: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 3s 339ms/step - loss: 0.2480 - lambda_3_loss: 0.0658 - lambda_4_loss: 0.0647
#
#
# Train generator.
# Epoch 321/321
#
# Epoch 00321: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 66s 662ms/step - loss: 5.5779 - D_model_loss: 9.9756 - predictions_loss: 3.3186
#
#
# Train discriminator.
# Epoch 321/321
#
# Epoch 00321: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 4s 358ms/step - loss: 0.2480 - lambda_3_loss: 0.3946 - lambda_4_loss: 0.0402
#
#
# Train generator.
# Epoch 322/322
#
# Epoch 00322: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 94s 938ms/step - loss: 5.5047 - D_model_loss: 9.6112 - predictions_loss: 3.2458 - val_loss: 6.8850 - val_D_model_loss: 0.1365 - val_predictions_loss: 4.6273
#
# Epoch 00322: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-322_loss-5.5047_val_loss-6.8850.h5
#
#
# Train discriminator.
# Epoch 322/322
#
# Epoch 00322: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 3s 346ms/step - loss: 0.2480 - lambda_3_loss: 0.6183 - lambda_4_loss: 0.2964
#
#
# Train generator.
# Epoch 323/323
#
# Epoch 00323: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 66s 662ms/step - loss: 5.5615 - D_model_loss: 9.5229 - predictions_loss: 3.3030
#
#
# Train discriminator.
# Epoch 323/323
#
# Epoch 00323: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 4s 357ms/step - loss: 0.2480 - lambda_3_loss: 0.6526 - lambda_4_loss: 0.0310
#
#
# Train generator.
# Epoch 324/324
#
# Epoch 00324: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 68s 682ms/step - loss: 5.5817 - D_model_loss: 9.6378 - predictions_loss: 3.3237
#
#
# Train discriminator.
# Epoch 324/324
#
# Epoch 00324: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 3s 332ms/step - loss: 0.2479 - lambda_3_loss: 0.0654 - lambda_4_loss: 0.0158
#
#
# Train generator.
# Epoch 325/325
#
# Epoch 00325: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 116s 1s/step - loss: 5.5085 - D_model_loss: 9.6300 - predictions_loss: 3.2509 - val_loss: 6.8707 - val_D_model_loss: 0.1502 - val_predictions_loss: 4.6143
#
# Epoch 00325: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-325_loss-5.5079_val_loss-6.8707.h5
#
#
# Train discriminator.
# Epoch 325/325
#
# Epoch 00325: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 4s 373ms/step - loss: 0.2479 - lambda_3_loss: 0.1932 - lambda_4_loss: 0.0343
#
#
# Train generator.
# Epoch 326/326
#
# Epoch 00326: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 66s 657ms/step - loss: 5.5972 - D_model_loss: 9.2674 - predictions_loss: 3.3401
#
#
# Train discriminator.
# Epoch 326/326
#
# Epoch 00326: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 4s 353ms/step - loss: 0.2479 - lambda_3_loss: 0.2528 - lambda_4_loss: 0.0545
#
#
# Train generator.
# Epoch 327/327
#
# Epoch 00327: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 69s 685ms/step - loss: 5.5326 - D_model_loss: 9.8288 - predictions_loss: 3.2758
#
#
# Train discriminator.
# Epoch 327/327
#
# Epoch 00327: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 4s 353ms/step - loss: 0.2479 - lambda_3_loss: 0.8205 - lambda_4_loss: 0.0560
#
#
# Train generator.
# Epoch 328/328
#
# Epoch 00328: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 160s 2s/step - loss: 5.6320 - D_model_loss: 9.6325 - predictions_loss: 3.3757 - val_loss: 6.9199 - val_D_model_loss: 0.1254 - val_predictions_loss: 4.6648
#
# Epoch 00328: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-328_loss-5.6302_val_loss-6.9199.h5
#
#
# Train discriminator.
# Epoch 328/328
#
# Epoch 00328: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 4s 377ms/step - loss: 0.2478 - lambda_3_loss: 0.5680 - lambda_4_loss: 0.0484
#
#
# Train generator.
# Epoch 329/329
#
# Epoch 00329: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 67s 672ms/step - loss: 5.5439 - D_model_loss: 9.3500 - predictions_loss: 3.2881
#
#
# Train discriminator.
# Epoch 329/329
#
# Epoch 00329: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 4s 388ms/step - loss: 0.2478 - lambda_3_loss: 0.1022 - lambda_4_loss: 0.2751
#
#
# Train generator.
# Epoch 330/330
#
# Epoch 00330: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 67s 671ms/step - loss: 5.4978 - D_model_loss: 9.2999 - predictions_loss: 3.2424
#
#
# Train discriminator.
# Epoch 330/330
#
# Epoch 00330: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 4s 362ms/step - loss: 0.2477 - lambda_3_loss: 0.1269 - lambda_4_loss: 0.0471
#
#
# Train generator.
# Epoch 331/331
#
# Epoch 00331: LearningRateScheduler setting learning rate to 0.0001.
# 100/100 [==============================] - 97s 970ms/step - loss: 5.5510 - D_model_loss: 9.8425 - predictions_loss: 3.2960 - val_loss: 6.9016 - val_D_model_loss: 0.1730 - val_predictions_loss: 4.6478
#
# Epoch 00331: saving model to ../trained_weights/SIM10K_to_City/current/G100_D10_GD_weights0_0001/epoch-331_loss-5.5510_val_loss-6.9016.h5
#
#
# Train discriminator.
# Epoch 331/331
#
# Epoch 00331: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 4s 385ms/step - loss: 0.2477 - lambda_3_loss: 0.0835 - lambda_4_loss: 0.0278
#
#
# Train generator.
# Epoch 332/332
#
# Epoch 00332: LearningRateScheduler setting learning rate to 0.0001.
#   2/100 [..............................] - ETA: 1:19 - loss: 5.2641 - D_model_loss: 9.7122 - predictions_loss: 3.0093

# %%
# 1: Set the generator for the val_dataset or train_dataset predictions.

predict_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=None,
                                         returns={'processed_images',
                                                  'filenames',
                                                  'inverse_transform',
                                                  'original_images',
                                                  'original_labels'},
                                         keep_images_without_gt=False)

# 2: Generate samples.

batch_images, batch_filenames, batch_inverse_transforms, batch_original_images, batch_original_labels = next(predict_generator)

# %%
batch_images, batch_filenames, batch_inverse_transforms, batch_original_images, batch_original_labels = next(predict_generator)

# %%
i = 1
print("Image:", batch_filenames[i])
colors = plt.cm.hsv(np.linspace(0, 1, n_classes+1)).tolist()

plt.figure(figsize=(20, 12))
plt.imshow(batch_images[0][i])
plt.show()
plt.figure(figsize=(20, 12))
plt.imshow(batch_images[1][i])
plt.show()

# %%
i = 0  # Which batch item to look at

print("Image:", batch_filenames[i])
print()
print("Ground truth boxes:\n")
print(np.array(batch_original_labels[i]))

# 3: Make predictions.

y_pred = model.predict(batch_images)[-1]

# Now let's decode the raw predictions in `y_pred`.

# Had we created the model in 'inference' or 'inference_fast' mode,
# then the model's final layer would be a `DecodeDetections` layer and
# `y_pred` would already contain the decoded predictions,
# but since we created the model in 'training' mode,
# the model outputs raw predictions that still need to be decoded and filtered.
# This is what the `decode_detections()` function is for.
# It does exactly what the `DecodeDetections` layer would do,
# but using Numpy instead of TensorFlow (i.e. on the CPU instead of the GPU).

# `decode_detections()` with default argument values follows the procedure of the original SSD implementation:
# First, a very low confidence threshold of 0.01 is applied to filter out the majority of the predicted boxes,
# then greedy non-maximum suppression is performed per class with an intersection-over-union threshold of 0.45,
# and out of what is left after that, the top 200 highest confidence boxes are returned.
# Those settings are for precision-recall scoring purposes though.
# In order to get some usable final predictions, we'll set the confidence threshold much higher, e.g. to 0.5,
# since we're only interested in the very confident predictions.

# 4: Decode the raw predictions in `y_pred`.

y_pred_decoded = decode_detections(y_pred,
                                   confidence_thresh=0.35,
                                   iou_threshold=0.4,
                                   top_k=200,
                                   normalize_coords=normalize_coords,
                                   img_height=img_height,
                                   img_width=img_width)

# We made the predictions on the resized images,
# but we'd like to visualize the outcome on the original input images,
# so we'll convert the coordinates accordingly.
# Don't worry about that opaque `apply_inverse_transforms()` function below,
# in this simple case it just applies `(* original_image_size / resized_image_size)` to the box coordinates.

# 5: Convert the predictions for the original image.

y_pred_decoded_inv = apply_inverse_transforms(y_pred_decoded, batch_inverse_transforms)

np.set_printoptions(precision=2, suppress=True, linewidth=90)
print("Predicted boxes:\n")
print('   class   conf xmin   ymin   xmax   ymax')
print(y_pred_decoded_inv[i])

# Finally, let's draw the predicted boxes onto the image.
# Each predicted box says its confidence next to the category name.
# The ground truth boxes are also drawn onto the image in green for comparison.

# 5: Draw the predicted boxes onto the image

# Set the colors for the bounding boxes
colors = plt.cm.hsv(np.linspace(0, 1, n_classes+1)).tolist()

plt.figure(figsize=(20, 12))
plt.imshow(batch_original_images[i])

current_axis = plt.gca()

for box in batch_original_labels[i]:
    xmin = box[1]
    ymin = box[2]
    xmax = box[3]
    ymax = box[4]
    label = '{}'.format(classes[int(box[0])])
    current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color='green', fill=False, linewidth=2))
    current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor': 'green', 'alpha': 1.0})

# for box in y_pred_decoded_inv[i]:
#     xmin = box[2]
#     ymin = box[3]
#     xmax = box[4]
#     ymax = box[5]
#     color = colors[int(box[0])]
#     label = '{}: {:.2f}'.format(classes[int(box[0])], box[1])
#     current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color=color, fill=False, linewidth=2))
#     current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor': color, 'alpha': 1.0})
